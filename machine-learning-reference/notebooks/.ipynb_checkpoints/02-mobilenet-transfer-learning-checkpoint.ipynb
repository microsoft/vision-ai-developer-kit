# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# # Transfer learning sample
# * Train model
# * Build Image
# * Create IoT Edge deployment JSON
# * Deploy Model

# %%
# For prod
# !pip install azureml-core
# !pip install azureml-contrib-iot
# !pip install azure-mgmt-containerregistry
# Out:
# Requirement already satisfied: azureml-core in c:\users\tedway\appdata\roaming\python\python36\site-packages (1.0.17.1)
# Requirement already satisfied: SecretStorage in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (2.3.1)
# Requirement already satisfied: jmespath in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (0.9.3)
# Requirement already satisfied: pyyaml>=3.13 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (3.13)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (2.7.5)
# Requirement already satisfied: docker in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (3.6.0)
# Requirement already satisfied: backports.tempfile in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (1.0)
# Requirement already satisfied: azure-mgmt-resource>=1.2.1 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (2.1.0)
# Requirement already satisfied: six>=1.11.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (1.12.0)
# Requirement already satisfied: pytz in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (2018.9)
# Requirement already satisfied: azure-graphrbac>=0.40.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (0.53.0)
# Requirement already satisfied: ndg-httpsclient in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (0.5.1)
# Requirement already satisfied: pyopenssl in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (18.0.0)
# Requirement already satisfied: azure-mgmt-keyvault>=0.40.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (1.1.0)
# Requirement already satisfied: jsonpickle in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (1.0)
# Requirement already satisfied: ruamel.yaml<=0.15.51,>=0.15.35 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (0.15.51)
# Requirement already satisfied: azure-common>=1.1.12 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (1.1.16)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (2.4.2)
# Requirement already satisfied: urllib3>=1.23 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (1.23)
# Requirement already satisfied: azure-mgmt-storage>=1.5.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (3.1.1)
# Requirement already satisfied: azure-mgmt-containerregistry>=2.0.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (2.6.0)
# Requirement already satisfied: PyJWT in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (1.7.1)
# Requirement already satisfied: msrestazure>=0.4.33 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (0.6.0)
# Requirement already satisfied: adal>=1.2.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (1.2.0)
# Requirement already satisfied: azure-mgmt-authorization>=0.40.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (0.51.1)
# Requirement already satisfied: requests>=2.19.1 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (2.21.0)
# Requirement already satisfied: contextlib2 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (0.5.5)
# Requirement already satisfied: pathspec in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (0.5.9)
# Requirement already satisfied: msrest>=0.5.1 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (0.6.4)
# Requirement already satisfied: paramiko>=2.0.8 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core) (2.4.2)
# Requirement already satisfied: pypiwin32==223; sys_platform == "win32" and python_version >= "3.6" in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from docker->azureml-core) (223)
# Requirement already satisfied: docker-pycreds>=0.3.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from docker->azureml-core) (0.4.0)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from docker->azureml-core) (0.54.0)
# Requirement already satisfied: backports.weakref in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from backports.tempfile->azureml-core) (1.0.post1)
# Requirement already satisfied: pyasn1>=0.1.1 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from ndg-httpsclient->azureml-core) (0.4.5)
# Requirement already satisfied: azure-mgmt-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azure-mgmt-keyvault>=0.40.0->azureml-core) (3.0.2)
# Requirement already satisfied: idna>=2.1 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6->azureml-core) (2.8)
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6->azureml-core) (1.11.5)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6->azureml-core) (0.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from requests>=2.19.1->azureml-core) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from requests>=2.19.1->azureml-core) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from msrest>=0.5.1->azureml-core) (1.1.0)
# Requirement already satisfied: isodate>=0.6.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from msrest>=0.5.1->azureml-core) (0.6.0)
# Requirement already satisfied: pynacl>=1.0.1 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from paramiko>=2.0.8->azureml-core) (1.3.0)
# Requirement already satisfied: bcrypt>=3.1.3 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from paramiko>=2.0.8->azureml-core) (3.1.5)
# Requirement already satisfied: pywin32>=223 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from pypiwin32==223; sys_platform == "win32" and python_version >= "3.6"->docker->azureml-core) (224)
# Requirement already satisfied: azure-nspkg>=3.0.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azure-mgmt-nspkg>=2.0.0->azure-mgmt-keyvault>=0.40.0->azureml-core) (3.0.2)
# Requirement already satisfied: pycparser in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from cffi!=1.11.3,>=1.7->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6->azureml-core) (2.19)
# Requirement already satisfied: oauthlib<3.0.0,>=2.1.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core) (2.1.0)
# Requirement already satisfied: azureml-contrib-iot in c:\users\tedway\appdata\roaming\python\python36\site-packages (1.0.17)
# Requirement already satisfied: azureml-core==1.0.17.* in c:\users\tedway\appdata\roaming\python\python36\site-packages (from azureml-contrib-iot) (1.0.17.1)
# Requirement already satisfied: SecretStorage in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (2.3.1)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (2.4.2)
# Requirement already satisfied: requests>=2.19.1 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (2.21.0)
# Requirement already satisfied: pytz in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (2018.9)
# Requirement already satisfied: azure-mgmt-storage>=1.5.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (3.1.1)
# Requirement already satisfied: azure-common>=1.1.12 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (1.1.16)
# Requirement already satisfied: msrest>=0.5.1 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (0.6.4)
# Requirement already satisfied: azure-mgmt-keyvault>=0.40.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (1.1.0)
# Requirement already satisfied: pyopenssl in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (18.0.0)
# Requirement already satisfied: six>=1.11.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (1.12.0)
# Requirement already satisfied: azure-mgmt-containerregistry>=2.0.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (2.6.0)
# Requirement already satisfied: adal>=1.2.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (1.2.0)
# Requirement already satisfied: azure-mgmt-authorization>=0.40.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (0.51.1)
# Requirement already satisfied: contextlib2 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (0.5.5)
# Requirement already satisfied: azure-graphrbac>=0.40.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (0.53.0)
# Requirement already satisfied: jmespath in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (0.9.3)
# Requirement already satisfied: msrestazure>=0.4.33 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (0.6.0)
# Requirement already satisfied: paramiko>=2.0.8 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (2.7.5)
# Requirement already satisfied: docker in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (3.6.0)
# Requirement already satisfied: backports.tempfile in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (1.0)
# Requirement already satisfied: pathspec in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (0.5.9)
# Requirement already satisfied: ruamel.yaml<=0.15.51,>=0.15.35 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (0.15.51)
# Requirement already satisfied: urllib3>=1.23 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (1.23)
# Requirement already satisfied: jsonpickle in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (1.0)
# Requirement already satisfied: azure-mgmt-resource>=1.2.1 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (2.1.0)
# Requirement already satisfied: pyyaml>=3.13 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (3.13)
# Requirement already satisfied: PyJWT in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (1.7.1)
# Requirement already satisfied: ndg-httpsclient in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azureml-core==1.0.17.*->azureml-contrib-iot) (0.5.1)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6->azureml-core==1.0.17.*->azureml-contrib-iot) (0.24.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6->azureml-core==1.0.17.*->azureml-contrib-iot) (1.11.5)
# Requirement already satisfied: idna>=2.1 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6->azureml-core==1.0.17.*->azureml-contrib-iot) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from requests>=2.19.1->azureml-core==1.0.17.*->azureml-contrib-iot) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from requests>=2.19.1->azureml-core==1.0.17.*->azureml-contrib-iot) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from msrest>=0.5.1->azureml-core==1.0.17.*->azureml-contrib-iot) (1.1.0)
# Requirement already satisfied: isodate>=0.6.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from msrest>=0.5.1->azureml-core==1.0.17.*->azureml-contrib-iot) (0.6.0)
# Requirement already satisfied: azure-mgmt-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azure-mgmt-keyvault>=0.40.0->azureml-core==1.0.17.*->azureml-contrib-iot) (3.0.2)
# Requirement already satisfied: pynacl>=1.0.1 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from paramiko>=2.0.8->azureml-core==1.0.17.*->azureml-contrib-iot) (1.3.0)
# Requirement already satisfied: bcrypt>=3.1.3 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from paramiko>=2.0.8->azureml-core==1.0.17.*->azureml-contrib-iot) (3.1.5)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from paramiko>=2.0.8->azureml-core==1.0.17.*->azureml-contrib-iot) (0.4.5)
# Requirement already satisfied: docker-pycreds>=0.3.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from docker->azureml-core==1.0.17.*->azureml-contrib-iot) (0.4.0)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from docker->azureml-core==1.0.17.*->azureml-contrib-iot) (0.54.0)
# Requirement already satisfied: pypiwin32==223; sys_platform == "win32" and python_version >= "3.6" in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from docker->azureml-core==1.0.17.*->azureml-contrib-iot) (223)
# Requirement already satisfied: backports.weakref in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from backports.tempfile->azureml-core==1.0.17.*->azureml-contrib-iot) (1.0.post1)
# Requirement already satisfied: pycparser in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from cffi!=1.11.3,>=1.7->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6->azureml-core==1.0.17.*->azureml-contrib-iot) (2.19)
# Requirement already satisfied: oauthlib<3.0.0,>=2.1.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core==1.0.17.*->azureml-contrib-iot) (2.1.0)
# Requirement already satisfied: azure-nspkg>=3.0.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azure-mgmt-nspkg>=2.0.0->azure-mgmt-keyvault>=0.40.0->azureml-core==1.0.17.*->azureml-contrib-iot) (3.0.2)
# Requirement already satisfied: pywin32>=223 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from pypiwin32==223; sys_platform == "win32" and python_version >= "3.6"->docker->azureml-core==1.0.17.*->azureml-contrib-iot) (224)
# Requirement already satisfied: azure-mgmt-containerregistry in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (2.6.0)
# Requirement already satisfied: msrestazure<2.0.0,>=0.4.32 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azure-mgmt-containerregistry) (0.6.0)
# Requirement already satisfied: azure-common~=1.1 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azure-mgmt-containerregistry) (1.1.16)
# Requirement already satisfied: msrest>=0.5.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from azure-mgmt-containerregistry) (0.6.4)
# Requirement already satisfied: adal<2.0.0,>=0.6.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (1.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from msrest>=0.5.0->azure-mgmt-containerregistry) (2018.11.29)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from msrest>=0.5.0->azure-mgmt-containerregistry) (1.1.0)
# Requirement already satisfied: requests~=2.16 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from msrest>=0.5.0->azure-mgmt-containerregistry) (2.21.0)
# Requirement already satisfied: isodate>=0.6.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from msrest>=0.5.0->azure-mgmt-containerregistry) (0.6.0)
# Requirement already satisfied: PyJWT>=1.0.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.1.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (2.7.5)
# Requirement already satisfied: cryptography>=1.1.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (2.4.2)
# Requirement already satisfied: oauthlib<3.0.0,>=2.1.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-mgmt-containerregistry) (2.1.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-mgmt-containerregistry) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-mgmt-containerregistry) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-mgmt-containerregistry) (1.23)
# Requirement already satisfied: six in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from isodate>=0.6.0->msrest>=0.5.0->azure-mgmt-containerregistry) (1.12.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (1.11.5)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (0.24.0)
# Requirement already satisfied: pycparser in c:\programdata\miniconda3\envs\iotedge\lib\site-packages (from cffi!=1.11.3,>=1.7->cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (2.19)

# %%
import os
print(os.__file__)
# Out:
# C:\ProgramData\Miniconda3\envs\iotedge\lib\os.py

# %%
# Check core SDK version number
import azureml.core as azcore

print("SDK version:", azcore.VERSION)
# Out:
# SDK version: 1.0.17

# %% [markdown]
# ### Create a Workspace
# #### Change this cell from markdown to code and run this if you need to create a workspace
# #### Update the values for your workspace below
# ws=Workspace.create(subscription_id="replace-with-subscription-id",
#                 resource_group="your-resource-group",
#                 name="your-workspace-name",
#                 location="eastus2")
#
# ws.write_config()

# %%
#Initialize Workspace 
from azureml.core import Workspace

ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.
# Found the config file in: C:\Users\tedway\git\vision-ai-developer-kit\machine-learning-reference\notebooks\aml_config\config.json
# aml-vdaik-1
# tedway-vienna1-rg
# eastus2
# 75f78a03-482f-4fd8-8c71-5ddc08f92726

# %% [markdown]
# ### Create Experiment
# Experiment is a logical container in an Azure ML Workspace. It hosts run records which can include run metrics and output artifacts from your experiments.

# %%
experiment_name = 'soda_cans'

from azureml.core import Experiment
exp = Experiment(workspace = ws, name = experiment_name)

# %% [markdown]
# ## Get data
# ### Option 1: Upload data files into datastore
# Every workspace comes with a default datastore (and you can register more) which is backed by the Azure blob storage account associated with the workspace. We can use it to transfer data from local to the cloud, and access it from the compute target.

# %%
# get the default datastore
ds = ws.get_default_datastore()
print(ds.name, ds.datastore_type, ds.account_name, ds.container_name)
# Out:
# workspaceblobstore AzureBlob amlvdaik14969151586 azureml-blobstore-1721629c-c5b4-4182-940b-a0cdff79ba52

# %%
data_path = experiment_name + '_training_data'
ds.upload(src_dir='data/soda_cans', target_path=data_path, overwrite=True)
# Out:
# Uploading data/soda_cans\coke\IMG_20181207_154649.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154652.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154654.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154656.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154659.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154671.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154672.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154673.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154701.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154704.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154706.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154708.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154710.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154712.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154714.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154724.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154726.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154732.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154735.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154737.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154739.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154741.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154743.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154746.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154748.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154750.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154752.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154756.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154758.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154800.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154802.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154804.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154714.jpg, 1 files out of an estimated total of 133
# Uploading data/soda_cans\coke\IMG_20181207_154805.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154704.jpg, 2 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154712.jpg, 3 files out of an estimated total of 133
# Uploading data/soda_cans\coke\IMG_20181207_154806.jpg
# Uploading data/soda_cans\duck\IMG_20181207_154919.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_
print(ds.name, ds.datastore_type, ds.account_name, ds.container_name)

# %% [markdown]
# ### Configure for using ACI
# Linux-based ACI is available in West US, East US, West Europe, North Europe, West US 2, Southeast Asia, Australia East, East US 2, and Central US regions.  See details [here](https://docs.microsoft.com/en-us/azure/container-instances/container-instances-quotas#region-availability)

# %%
from azureml.core.runconfig import DataReferenceConfiguration
dr = DataReferenceConfiguration(datastore_name=ds.name, 
                   path_on_datastore=data_path, 
                   mode='download', # download files from datastore to compute target
                   overwrite=True)

# %% [markdown]
# Set the system to build a conda environment based on the run configuration. Once the environment is built, and if you don't change your dependencies, it will be reused in subsequent runs.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# choose a name for your cluster
cluster_name = "cpucluster1"

try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing compute target.')
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_D3', max_nodes=2)

    # create the cluster
    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

    compute_target.wait_for_completion(show_output=True)

# Use the 'status' property to get a detailed status for the current AmlCompute. 
print(compute_target.status.serialize())
# Out:
# Found existing compute target.
# {'allocationState': 'Steady', 'allocationStateTransitionTime': '2019-02-14T08:26:56.459000+00:00', 'creationTime': '2019-01-09T23:59:06.540668+00:00', 'currentNodeCount': 0, 'errors': None, 'modifiedTime': '2019-01-09T23:59:44.897457+00:00', 'nodeStateCounts': {'idleNodeCount': 0, 'leavingNodeCount': 0, 'preemptedNodeCount': 0, 'preparingNodeCount': 0, 'runningNodeCount': 0, 'unusableNodeCount': 0}, 'provisioningState': 'Succeeded', 'provisioningStateTransitionTime': None, 'scaleSettings': {'minNodeCount': 0, 'maxNodeCount': 2, 'nodeIdleTimeBeforeScaleDown': 'PT120S'}, 'targetNodeCount': 0, 'vmPriority': 'Dedicated', 'vmSize': 'STANDARD_D3'}

# %%
from azureml.core.runconfig import RunConfiguration, DEFAULT_CPU_IMAGE
from azureml.core.conda_dependencies import CondaDependencies

# create a new runconfig object
run_config = RunConfiguration(framework = "python")

# Set compute target
run_config.target = compute_target.name

# set the data reference of the run configuration
run_config.data_references = {ds.name: dr}

# enable Docker 
run_config.environment.docker.enabled = True

# set Docker base image to the default CPU-based image
run_config.environment.docker.base_image = DEFAULT_CPU_IMAGE

# use conda_dependencies.yml to create a conda environment in the Docker image for execution
run_config.environment.python.user_managed_dependencies = False

# auto-prepare the Docker image when used for execution (if it is not already prepared)
run_config.auto_prepare_environment = True

# specify CondaDependencies obj
run_config.environment.python.conda_dependencies = CondaDependencies.create(conda_packages=['tensorflow==1.8.0'])

# %% [markdown]
# ### Submit the Experiment
# Submit script to run in the Docker image in the remote VM. If you run this for the first time, the system will download the base image, layer in packages specified in the conda_dependencies.yml file on top of the base image, create a container and then execute the script in the container.

# %%
from azureml.core import Run
from azureml.core import ScriptRunConfig

src = ScriptRunConfig(source_directory = './02-mobilenet-transfer-learning-scripts', script = 'retrain.py', run_config = run_config, 
                      # pass the datastore reference as a parameter to the training script
                      arguments=['--image_dir', str(ds.as_download()),
                                 '--architecture', 'mobilenet_1.0_224',
                                 '--output_graph', 'outputs/retrained_graph.pb',
                                 '--output_labels', 'outputs/output_labels.txt',
                                 '--model_download_url', 'https://raw.githubusercontent.com/rakelkar/models/master/model_output/',
                                 '--model_file_name', 'imagenet_2_frozen.pb'
                                ])
run = exp.submit(config=src)

# %%
run
# Out:
# Run(Experiment: soda_cans,
# Id: soda_cans_1551993763_a5d18168,
# Type: azureml.scriptrun,
# Status: Starting)

# %%
run.wait_for_completion(show_output=True)
# Out:
# RunId: soda_cans_1551993763_a5d18168
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2019/03/07 21:23:01 Using acb_vol_1b7cf443-53e0-47f0-9262-1a305c909fb5 as the home volume
# 2019/03/07 21:23:01 Creating Docker network: acb_default_network, driver: 'bridge'
# 2019/03/07 21:23:01 Successfully set up Docker network: acb_default_network
# 2019/03/07 21:23:01 Setting up Docker configuration...
# 2019/03/07 21:23:02 Successfully set up Docker configuration
# 2019/03/07 21:23:02 Logging in to registry: amlvdaik10491222845.azurecr.io
# 2019/03/07 21:23:03 Successfully logged into amlvdaik10491222845.azurecr.io
# 2019/03/07 21:23:03 Executing step ID: acb_step_0. Working directory: '', Network: 'acb_default_network'
# 2019/03/07 21:23:03 Obtaining source code and scanning for dependencies...
# 2019/03/07 21:23:04 Successfully obtained source code and scanned for dependencies
# 2019/03/07 21:23:04 Launching container with name: acb_step_0
# Sending build context to Docker daemon  40.96kB
#
# Step 1/13 : FROM mcr.microsoft.com/azureml/base:0.2.2
# 0.2.2: Pulling from azureml/base
# 7b722c1070cd: Already exists
# 5fbf74db61f1: Already exists
# ed41cb72e5c9: Already exists
# 7ea47a67709e: Already exists
# d89051e8f8b7: Pulling fs layer
# b2baaa72394d: Pulling fs layer
# 4eca5d311ae6: Pulling fs layer
# ff9c6767bfb6: Pulling fs layer
# ff9c6767bfb6: Waiting
# d89051e8f8b7: Verifying Checksum
# d89051e8f8b7: Download complete
# ff9c6767bfb6: Verifying Checksum
# ff9c6767bfb6: Download complete
# 4eca5d311ae6: Verifying Checksum
# 4eca5d311ae6: Download complete
# b2baaa72394d: Verifying Checksum
# b2baaa72394d: Download complete
# d89051e8f8b7: Pull complete
# b2baaa72394d: Pull complete
# 4eca5d311ae6: Pull complete
# ff9c6767bfb6: Pull complete
# Digest: sha256:1f99439cb2a568417a8063dac75810d61795bbf70b5aacd4a1d05c1d89f5f536
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:0.2.2
#  ---> 1209a571c219
# Step 2/13 : USER root
#  ---> Running in 715e62f6f1b2
# Removing intermediate container 715e62f6f1b2
#  ---> 5b3ef00dce44
# Step 3/13 : RUN mkdir -p $HOME/.cache
#  ---> Running in c65c0b2b3cd6
# Removing intermediate container c65c0b2b3cd6
#  ---> f716a2c04aba
# Step 4/13 : WORKDIR /
#  ---> Running in 63498a25b2c8
# Removing intermediate container 63498a25b2c8
#  ---> 7c25e3cfba51
# Step 5/13 : COPY azureml-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 017ea62e9e5b
# Step 6/13 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.0; then conda install conda==4.4.11; fi
#  ---> Running in f150055fbeb7
# Removing intermediate container f150055fbeb7
#  ---> 0213fe706bb1
# Step 7/13 : COPY azureml-setup/mutated_conda_dependencies.yml azureml-setup/mutated_conda_dependencies.yml
#  ---> 8f6d38a73d24
# Step 8/13 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_bc67e4d88bad72d924dab7079c5045df -f azureml-setup/mutated_conda_dependencies.yml && ldconfig
#  ---> Running in dc161961dfa9
# Solving environment: ...working... done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.6.7
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# grpcio-1.14.1        | 1.0 MB    |            |   0%
# grpcio-1.14.1        | 1.0 MB    | ########   |  80%
# grpcio-1.14.1        | 1.0 MB    | #########8 |  98%
# grpcio-1.14.1        | 1.0 MB    | ########## | 100%
#
# gast-0.2.2           | 138 KB    |            |   0%
# gast-0.2.2           | 138 KB    | ########## | 100%
#
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    | #######6   |  77%
# tk-8.6.8             | 3.1 MB    | ########6  |  87%
# tk-8.6.8             | 3.1 MB    | #########4 |  95%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
#
# html5lib-0.9999999   | 176 KB    |            |   0%
# html5lib-0.9999999   | 176 KB    | ########## | 100%
#
# pip-19.0.3           | 1.9 MB    |            |   0%
# pip-19.0.3           | 1.9 MB    | #######9   |  79%
# pip-19.0.3           | 1.9 MB    | #########4 |  94%
# pip-19.0.3           | 1.9 MB    | ########## | 100%
#
# tensorflow-base-1.8. | 71.9 MB   |            |   0%
# tensorflow-base-1.8. | 71.9 MB   | 7          |   8%
# tensorflow-base-1.8. | 71.9 MB   | #3         |  13%
# tensorflow-base-1.8. | 71.9 MB   | #6         |  17%
# tensorflow-base-1.8. | 71.9 MB   | ##4        |  25%
# tensorflow-base-1.8. | 71.9 MB   | ###3       |  33%
# tensorflow-base-1.8. | 71.9 MB   | ####1      |  41%
# tensorflow-base-1.8. | 71.9 MB   | ####8      |  49%
# tensorflow-base-1.8. | 71.9 MB   | #####6     |  57%
# tensorflow-base-1.8. | 71.9 MB   | ######4    |  65%
# tensorflow-base-1.8. | 71.9 MB   | #######5   |  75%
# tensorflow-base-1.8. | 71.9 MB   | ########3  |  83%
# tensorflow-base-1.8. | 71.9 MB   | ########9  |  89%
# tensorflow-base-1.8. | 71.9 MB   | #########3 |  93%
# tensorflow-base-1.8. | 71.9 MB   | #########6 |  96%
# tensorflow-base-1.8. | 71.9 MB   | #########8 |  98%
# tensorflow-base-1.8. | 71.9 MB   | #########9 | 100%
# tensorflow-base-1.8. | 71.9 MB   | ########## | 100%
#
# openssl-1.0.2r       | 3.2 MB    |            |   0%
# openssl-1.0.2r       | 3.2 MB    | #######6   |  76%
# openssl-1.0.2r       | 3.2 MB    | #########4 |  94%
# openssl-1.0.2r       | 3.2 MB    | ########## | 100%
#
# readline-7.0         | 1.1 MB    |            |   0%
# readline-7.0         | 1.1 MB    | ########3  |  83%
# readline-7.0         | 1.1 MB    | ########## | 100%
#
# intel-openmp-2019.1  | 885 KB    |            |   0%
# intel-openmp-2019.1  | 885 KB    | ########8  |  89%
# intel-openmp-2019.1  | 885 KB    | ########## | 100%
#
# libstdcxx-ng-8.2.0   | 2.9 MB    |            |   0%
# libstdcxx-ng-8.2.0   | 2.9 MB    | #######7   |  77%
# libstdcxx-ng-8.2.0   | 2.9 MB    | ########## | 100%
#
# ncurses-6.0          | 920 KB    |            |   0%
# ncurses-6.0          | 920 KB    | #######9   |  79%
# ncurses-6.0          | 920 KB    | #########  |  90%
# ncurses-6.0          | 920 KB    | ########## | 100%
#
# mkl_random-1.0.2     | 407 KB    |            |   0%
# mkl_random-1.0.2     | 407 KB    | ########## | 100%
#
# ca-certificates-2019 | 126 KB    |            |   0%
# ca-certificates-2019 | 126 KB    | ########## | 100%
#
# markdown-3.0.1       | 107 KB    |            |   0%
# markdown-3.0.1       | 107 KB    | ########## | 100%
#
# astor-0.7.1          | 43 KB     |            |   0%
# astor-0.7.1          | 43 KB     | ########## | 100%
#
# setuptools-40.8.0    | 647 KB    |            |   0%
# setuptools-40.8.0    | 647 KB    | ########4  |  85%
# setuptools-40.8.0    | 647 KB    | ########## | 100%
#
# wheel-0.33.1         | 39 KB     |            |   0%
# wheel-0.33.1         | 39 KB     | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #4         |  14%
# python-3.6.2         | 27.0 MB   | ####3      |  43%
# python-3.6.2         | 27.0 MB   | #######5   |  75%
# python-3.6.2         | 27.0 MB   | #########2 |  93%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# protobuf-3.6.1       | 616 KB    |            |   0%
# protobuf-3.6.1       | 616 KB    | ########3  |  83%
# protobuf-3.6.1       | 616 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# werkzeug-0.14.1      | 423 KB    |            |   0%
# werkzeug-0.14.1      | 423 KB    | #########2 |  92%
# werkzeug-0.14.1      | 423 KB    | ########## | 100%
#
# absl-py-0.7.0        | 156 KB    |            |   0%
# absl-py-0.7.0        | 156 KB    | ########## | 100%
#
# certifi-2018.11.29   | 146 KB    |            |   0%
# certifi-2018.11.29   | 146 KB    | ########## | 100%
#
# termcolor-1.1.0      | 7 KB      |            |   0%
# termcolor-1.1.0      | 7 KB      | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########   |  80%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# libgcc-ng-8.2.0      | 7.6 MB    |            |   0%
# libgcc-ng-8.2.0      | 7.6 MB    | ######8    |  68%
# libgcc-ng-8.2.0      | 7.6 MB    | ########8  |  89%
# libgcc-ng-8.2.0      | 7.6 MB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | #######9   |  79%
# libgfortran-ng-7.3.0 | 1.3 MB    | #########8 |  99%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# numpy-1.16.2         | 49 KB     |            |   0%
# numpy-1.16.2         | 49 KB     | ########## | 100%
#
# c-ares-1.15.0        | 98 KB     |            |   0%
# c-ares-1.15.0        | 98 KB     | ########## | 100%
#
# numpy-base-1.16.2    | 4.4 MB    |            |   0%
# numpy-base-1.16.2    | 4.4 MB    | #######6   |  76%
# numpy-base-1.16.2    | 4.4 MB    | #########3 |  93%
# numpy-base-1.16.2    | 4.4 MB    | ########## | 100%
# xz-5.2.4             | 366 KB    |            |   0%
# xz-5.2.4             | 366 KB    | #########4 |  95%
# xz-5.2.4             | 366 KB    | ########## | 100%
#
# tensorflow-1.8.0     | 3 KB      |            |   0%
# tensorflow-1.8.0     | 3 KB      | ########## | 100%
#
# tensorboard-1.8.0    | 3.1 MB    |            |   0%
# tensorboard-1.8.0    | 3.1 MB    | #######6   |  76%
# tensorboard-1.8.0    | 3.1 MB    | #########8 |  99%
# tensorboard-1.8.0    | 3.1 MB    | ########## | 100%
#
# mkl-2019.1           | 204.6 MB  |            |   0%
# mkl-2019.1           | 204.6 MB  | 1          |   2%
# mkl-2019.1           | 204.6 MB  | 4          |   5%
# mkl-2019.1           | 204.6 MB  | 7          |   8%
# mkl-2019.1           | 204.6 MB  | #1         |  11%
# mkl-2019.1           | 204.6 MB  | #4         |  15%
# mkl-2019.1           | 204.6 MB  | #8         |  18%
# mkl-2019.1           | 204.6 MB  | ##1        |  22%
# mkl-2019.1           | 204.6 MB  | ##5        |  25%
# mkl-2019.1           | 204.6 MB  | ##9        |  29%
# mkl-2019.1           | 204.6 MB  | ###3       |  33%
# mkl-2019.1           | 204.6 MB  | ###7       |  37%
# mkl-2019.1           | 204.6 MB  | ####       |  41%
# mkl-2019.1           | 204.6 MB  | ####4      |  44%
# mkl-2019.1           | 204.6 MB  | ####8      |  48%
# mkl-2019.1           | 204.6 MB  | #####1     |  52%
# mkl-2019.1           | 204.6 MB  | #####5     |  56%
# mkl-2019.1           | 204.6 MB  | #####9     |  59%
# mkl-2019.1           | 204.6 MB  | ######2    |  63%
# mkl-2019.1           | 204.6 MB  | ######6    |  67%
# mkl-2019.1           | 204.6 MB  | #######    |  71%
# mkl-2019.1           | 204.6 MB  | #######4   |  75%
# mkl-2019.1           | 204.6 MB  | #######8   |  79%
# mkl-2019.1           | 204.6 MB  | ########1  |  81%
# mkl-2019.1           | 204.6 MB  | ########3  |  83%
# mkl-2019.1           | 204.6 MB  | ########4  |  85%
# mkl-2019.1           | 204.6 MB  | ########5  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | ########## | 100%
# mkl_fft-1.0.10       | 170 KB    |            |   0%
# mkl_fft-1.0.10       | 170 KB    | ########## | 100%
#
# _tflow_select-1.2.0  | 2 KB      |            |   0%
# _tflow_select-1.2.0  | 2 KB      | ########## | 100%
#
# libprotobuf-3.6.1    | 4.1 MB    |            |   0%
# libprotobuf-3.6.1    | 4.1 MB    | #######6   |  76%
# libprotobuf-3.6.1    | 4.1 MB    | #########9 |  99%
# libprotobuf-3.6.1    | 4.1 MB    | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# bleach-1.5.0         | 22 KB     |            |   0%
# bleach-1.5.0         | 22 KB     | ########## | 100%
#
# six-1.12.0           | 22 KB     |            |   0%
# six-1.12.0           | 22 KB     | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting azureml-defaults==1.0.17 (from -r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/64/0a/e1c2b6e2a591dda0a1a8ee3a143264484d1db46fef80eb34f652ac7a3846/azureml_defaults-1.0.17-py2.py3-none-any.whl
# Collecting azureml-core==1.0.17.* (from azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/54/8e/4e57078e34ce48d089c5e427327ebdb7a5002d807140a90948c3635bfc2e/azureml_core-1.0.17.1-py2.py3-none-any.whl (719kB)
# Collecting applicationinsights>=0.11.7 (from azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e3/c8/7848a0dd85158930b859eb8be1e38fc76a91f0a040d491723ebb356d7358/applicationinsights-0.11.7-py2.py3-none-any.whl (56kB)
# Collecting pytz (from azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/61/28/1d3920e4d1d50b19bc5d24398a7cd85cc7b9a75a490570d5a30c57622d34/pytz-2018.9-py2.py3-none-any.whl (510kB)
# Collecting ruamel.yaml<=0.15.51,>=0.15.35 (from azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d2/7f/9bb3ba89ceab600c4a0ea75d638ea945215ca3458ac6528e0e39fa3254e4/ruamel.yaml-0.15.51-cp36-cp36m-manylinux1_x86_64.whl (640kB)
# Collecting requests>=2.19.1 (from azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/7d/e3/20f3d364d6c8e5d2353c72a67778eb189176f08e873c9900e10c0287b84b/requests-2.21.0-py2.py3-none-any.whl (57kB)
# Collecting contextlib2 (from azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a2/71/8273a7eeed0aff6a854237ab5453bc9aa67deb49df4832801c21f0ff3782/contextlib2-0.5.5-py2.py3-none-any.whl
# Collecting ndg-httpsclient (from azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Collecting pathspec (from azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/84/2a/bfee636b1e2f7d6e30dd74f49201ccfa5c3cf322d44929ecc6c137c486c5/pathspec-0.5.9.tar.gz
# Collecting SecretStorage (from azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages
from azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/da/a8/3d3d6fe8458b2b07bad10195c79928ea9ba87b5cc0c08903b387dd27c6f0/azure_graphrbac-0.53.0-py2.py3-none-any.whl (108kB)
# Collecting azure-common>=1.1.12 (from azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c3/f8/46248b201fd38b7e93c6da644e2fc3bc5a39118f253562751fd295a8cc77/azure_common-1.1.18-py2.py3-none-any.whl
# Collecting azure-mgmt-storage>=1.5.0 (from azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d9/87/ab44b9d9627ff91825ba5f5a39092ebfe97a90679008609db4c479036591/azure_mgmt_storage-3.1.1-py2.py3-none-any.whl (696kB)
# Collecting msrest>=0.5.1 (from azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/eb/96/1cf56e4cfd221b7f6eb6ab096dc23b0d21361393f0784276531e49b0b2a1/msrest-0.6.4-py2.py3-none-any.whl (81kB)
# Collecting PyJWT (from azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Collecting jsonpickle (from azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/dc/12/8c44eabb501e2bc0aec0dd152b328074d98a50968d3a02be28f6037f0c6a/jsonpickle-1.1-py2.py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_bc67e4d88bad72d924dab7079c5045df/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1)) (2018.11.29)
# Collecting idna<2.9,>=2.5 (from requests>=2.19.1->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
# Collecting chardet<3.1.0,>=3.0.2 (from requests>=2.19.1->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Collecting pyasn1>=0.1.1 (from ndg-httpsclient->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/7b/7c/c9386b82a25115cccf1903441bba3cbadcfae7b678a20167347fa8ded34c/pyasn1-0.4.5-py2.py3-none-any.whl (73kB)
# Collecting jeepney (from SecretStorage->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/2b/f7/ff23b9b59534f501d47c327576aadda59da5b83d76ff837e6075bc325b9f/jeepney-0.4-py3-none-any.whl (59kB)
# Collecting backports.weakref (from backports.tempfile->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Collecting websocket-client>=0.32.0 (from docker->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/38/54/684db2ba1b7a203602808446b8686ee786f93b4a7e080cdc440cc7e06e56/websocket_client-0.55.0-py2.py3-none-any.whl (200kB)
# Collecting docker-pycreds>=0.4.0 (from docker->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Collecting asn1crypto>=0.21.0 (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ea/cd/35485615f45f30a510576f1a56d1e0a7ad7bd8ab5ed7cdc600ef7cd06222/asn1crypto-0.24.0-py2.py3-none-any.whl (101kB)
# Collecting cffi!=1.11.3,>=1.8 (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/20/f7/87b62a8895bf7c93e907b05b97bc4459c81a38a61151f03a6eae13d863aa/cffi-1.12.2-cp36-cp36m-manylinux1_x86_64.whl (428kB)
# Collecting pynacl>=1.0.1 (from paramiko>=2.0.8->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/27/15/2cd0a203f318c2240b42cd9dd13c931ddd61067809fee3479f44f086103e/PyNaCl-1.3.0-cp34-abi3-manylinux1_x86_64.whl (759kB)
# Collecting bcrypt>=3.1.3 (from paramiko>=2.0.8->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d0/79/79a4d167a31cc206117d9b396926615fa9c1fdbd52017bcced80937ac501/bcrypt-3.1.6-cp34-abi3-manylinux1_x86_64.whl (55kB)
# Collecting azure-mgmt-nspkg>=2.0.0 (from azure-mgmt-keyvault>=0.40.0->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b3/c2/af4b47845f27dc7d206ed4908b9e580f8bc94a4b2f3956a0d87c40719d90/azure_mgmt_nspkg-3.0.2-py3-none-any.whl
# Collecting isodate>=0.6.0 (from msrest>=0.5.1->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.5.1->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Collecting pycparser (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/68/9e/49196946aee219aead1290e00d1e7fdeab8567783e83e1b9ab5585e6206a/pycparser-2.19.tar.gz (158kB)
# Collecting azure-nspkg>=3.0.0 (from azure-mgmt-nspkg>=2.0.0->azure-mgmt-keyvault>=0.40.0->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c4/0c/c562be95a9a2ed52454f598571cf300b1114d0db2aa27f5b8ed3bb9cd0c0/azure_nspkg-3.0.2-py3-none-any.whl
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core==1.0.17.*->azureml-defaults==1.0.17->-r /azureml-setup/condaenv.vml6stvl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/16/95/699466b05b72b94a41f662dc9edf87fda4289e3602ecd42d27fcaddf7b56/oauthlib-3.0.1-py2.py3-none-any.whl (142kB)
# Building wheels for collected packages: pathspec, pyyaml, pycparser
#   Building wheel for pathspec (setup.py): started
#   Building wheel for pathspec (setup.py): finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/45/cb/7e/ce6e6062c69446e39e328170524ca8213498bc66a74c6a210b
#   Building wheel for pyyaml (setup.py): started
#   Building wheel for pyyaml (setup.py): finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/ad/da/0c/74eb680767247273e2cf2723482cb9c924fe70af57c334513f
#   Building wheel for pycparser (setup.py): started
#   Building wheel for pycparser (setup.py): finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/f2/9a/90/de94f8556265ddc9d9c8b271b0f63e57b26fb1d67a45564511
# Successfully built pathspec pyyaml pycparser
# Installing collected packages: pytz, ruamel.yaml, idna, chardet, urllib3, requests, contextlib2, pyasn1, asn1crypto, pycparser, cffi, cryptography, pyopenssl, ndg-httpsclient, pathspec, jeepney, SecretStorage, backports.weakref, backports.tempfile, PyJWT, python-dateutil, adal, websocket-client, docker-pycreds, docker, azure-common, isodate, oauthlib, requests-oauthlib, msrest, msrestazure, azure-mgmt-resource, pynacl, bcrypt, paramiko, azure-nspkg, azure-mgmt-nspkg, azure-mgmt-keyvault, pyyaml, azure-mgmt-containerregistry, azure-mgmt-authorization, jmespath, azure-graphrbac, azure-mgmt-storage, jsonpickle, azureml-core, applicationinsights, azureml-defaults
# Successfully installed PyJWT-1.7.1 SecretStorage-3.1.1 adal-1.2.1 applicationinsights-0.11.7 asn1crypto-0.24.0 azure-common-1.1.18 azure-graphrbac-0.53.0 azure-mgmt-authorization-0.51.1 azure-mgmt-containerregistry-2.7.0 azure-mgmt-keyvault-1.1.0 azure-mgmt-nspkg-3.0.2 azure-mgmt-resource-2.1.0 azure-mgmt-storage-3.1.1 azure-nspkg-3.0.2 azureml-core-1.0.17.1 azureml-defaults-1.0.17 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.1.6 cffi-1.12.2 chardet-3.0.4 contextlib2-0.5.5 cryptography-2.5 docker-3.7.0 docker-pycreds-0.4.0 idna-2.8 isodate-0.6.0 jeepney-0.4 jmespath-0.9.4 jsonpickle-1.1 msrest-0.6.4 msrestazure-0.6.0 ndg-httpsclient-0.5.1 oauthlib-3.0.1 paramiko-2.4.2 pathspec-0.5.9 pyasn1-0.4.5 pycparser-2.19 pynacl-1.3.0 pyopenssl-19.0.0 python-dateutil-2.8.0 pytz-2018.9 pyyaml-3.13 requests-2.21.0 requests-oauthlib-1.2.0 ruamel.yaml-0.15.51 urllib3-1.24.1 websocket-client-0.55.0
#
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_bc67e4d88bad72d924dab7079c5045df
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
# Removing intermediate container dc161961dfa9
#  ---> c170a8967d0f
# Step 9/13 : ENV PATH /azureml-envs/azureml_bc67e4d88bad72d924dab7079c5045df/bin:$PATH
#  ---> Running in ea688988b3d7
# Removing intermediate container ea688988b3d7
#  ---> 70f4703702b1
# Step 10/13 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_bc67e4d88bad72d924dab7079c5045df/lib:$LD_LIBRARY_PATH
#  ---> Running in 5ff2c37e1d11
# Removing intermediate container 5ff2c37e1d11
#  ---> b2a6edb17b97
# Step 11/13 : COPY azureml-setup/spark_cache.py azureml-setup/log4j.properties /azureml-setup/
#  ---> 7915b272324a
# Step 12/13 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit "--repositories" "https://mmlspark.azureedge.net/maven" "--packages" "com.microsoft.ml.spark:mmlspark_2.11:0.12" /azureml-setup/spark_cache.py'; fi
#  ---> Running in a88f135369b8
# Removing intermediate container a88f135369b8
#  ---> 273c42e20bac
# Step 13/13 : CMD ["bash"]
#  ---> Running in 7edff1c45320
# Removing intermediate container 7edff1c45320
#  ---> 0c3e504f6afd
# Successfully built 0c3e504f6afd
# Successfully tagged amlvdaik10491222845.azurecr.io/azureml/azureml_d48130e9f85e269656916d2ed3899d48:latest
# 2019/03/07 21:26:06 Successfully executed container: acb_step_0
# 2019/03/07 21:26:06 Executing step ID: acb_step_1. Working directory: '', Network: 'acb_default_network'
# 2019/03/07 21:26:06 Pushing image: amlvdaik10491222845.azurecr.io/azureml/azureml_d48130e9f85e269656916d2ed3899d48:latest, attempt 1
# The push refers to repository [amlvdaik10491222845.azurecr.io/azureml/azureml_d48130e9f85e269656916d2ed3899d48]
# afdca7963738: Preparing
# 37d088bd0c0b: Preparing
# 2b216c006cbc: Preparing
# 598c1f5f87ed: Preparing
# baf9a003835a: Preparing
# 8e4116665f41: Preparing
# b5ddc24bf34c: Preparing
# b9b752410ec8: Preparing
# 21fbf957df81: Preparing
# 7892a29094c3: Preparing
# 68dda0c9a8cd: Preparing
# f67191ae09b8: Preparing
# b2fd8b4c3da7: Preparing
# 0de2edf7bff4: Preparing
# 8e4116665f41: Waiting
# b5ddc24bf34c: Waiting
# b9b752410ec8: Waiting
# 21fbf957df81: Waiting
# 7892a29094c3: Waiting
# 68dda0c9a8cd: Waiting
# f67191ae09b8: Waiting
# b2fd8b4c3da7: Waiting
# 0de2edf7bff4: Waiting
# 2b216c006cbc: Pushed
# 598c1f5f87ed: Pushed
# baf9a003835a: Pushed
# afdca7963738: Pushed
# 8e4116665f41: Pushed
# b5ddc24bf34c: Pushed
# 68dda0c9a8cd: Pushed
# f67191ae09b8: Pushed
# b2fd8b4c3da7: Pushed
# 7892a29094c3: Pushed
# 21fbf957df81: Pushed
# 0de2edf7bff4: Pushed
# b9b752410ec8: Pushed
# 37d088bd0c0b: Pushed
# latest: digest: sha256:895ff3d893cce34831b1f555f4a3cb24c1e105a7856cfcb483d2fb011cc21aa9 size: 3248
# 2019/03/07 21:28:47 Successfully pushed image: amlvdaik10491222845.azurecr.io/azureml/azureml_d48130e9f85e269656916d2ed3899d48:latest
# 2019/03/07 21:28:47 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 182.292969)
# 2019/03/07 21:28:47 Populating digests for step ID: acb_step_0...
# 2019/03/07 21:28:49 Successfully populated digests for step ID: acb_step_0
# 2019/03/07 21:28:49 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 161.282266)
# 2019/03/07 21:28:49 The following dependencies were found:
# 2019/03/07 21:28:49
# - image:
#     registry: amlvdaik10491222845.azurecr.io
#     repository: azureml/azureml_d48130e9f85e269656916d2ed3899d48
#     tag: latest
#     digest: sha256:895ff3d893cce34831b1f555f4a3cb24c1e105a7856cfcb483d2fb011cc21aa9
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: 0.2.2
#     digest: sha256:1f99439cb2a568417a8063dac75810d61795bbf70b5aacd4a1d05c1d89f5f536
#   git: {}
#
#
# Run ID: chs was successful after 5m57s
#
# Streaming azureml-logs/60_control_log.txt
# =========================================
#
# Streaming log file azureml-logs/60_control_log.txt
# Streaming log file azureml-logs/80_driver_log.txt
#
# Streaming azureml-logs/80_driver_log.txt
# ========================================
#
# Downloading soda_cans_training_data/coke/IMG_20181207_154649.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154652.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154654.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154656.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154659.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154671.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154672.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154673.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154701.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154704.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154706.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154708.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154710.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154712.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154714.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154724.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154726.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154732.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154735.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154737.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154739.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154741.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154743.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154746.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154748.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154750.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154752.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154756.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154758.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154800.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154802.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154804.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154649.jpg, 1 files out of an estimated total of 133
# Downloading soda_cans_training_data/coke/IMG_20181207_154805.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154652.jpg, 2 files out of an estimated total of 133
# Downloading soda_cans_training_data/coke/IMG_20181207_154806.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154654.jpg, 3 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154919.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154659.jpg, 4 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154922.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154671.jpg, 5 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154925.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154672.jpg, 6 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154927.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154673.jpg, 7 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154929.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154706.jpg, 8 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154931.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154701.jpg, 9 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154933.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154704.jpg, 10 files out of an estimated total of 133
# ...
# INFO:tensorflow:2019-03-07 21:42:46.880449: Step 3550: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-03-07 21:42:47.548852: Step 3560: Train accuracy = 100.0%
# INFO:tensorflow:2019-03-07 21:42:47.549069: Step 3560: Cross entropy = 0.000458
# INFO:tensorflow:2019-03-07 21:42:47.614119: Step 3560: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-03-07 21:42:48.307374: Step 3570: Train accuracy = 100.0%
# INFO:tensorflow:2019-03-07 21:42:48.307597: Step 3570: Cross entropy = 0.000266
# INFO:tensorflow:2019-03-07 21:42:48.375126: Step 3570: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-03-07 21:42:49.043130: Step 3580: Train accuracy = 100.0%
# INFO:tensorflow:2019-03-07 21:42:49.043348: Step 3580: Cross entropy = 0.000284
# INFO:tensorflow:2019-03-07 21:42:49.109270: Step 3580: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-03-07 21:42:49.772005: Step 3590: Train accuracy = 100.0%
# INFO:tensorflow:2019-03-07 21:42:49.772215: Step 3590: Cross entropy = 0.000187
# INFO:tensorflow:2019-03-07 21:42:49.836851: Step 3590: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-03-07 21
Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:Final test accuracy = 100.0% (N=14)
# INFO:tensorflow:Froze 2 variables.
# Converted 2 variables to const ops.
#
#
# The experiment completed successfully. Finalizing run...
# Logging experiment finalizing status in history service
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 1 items cleaning up...
# Cleanup took 0.10180282592773438 seconds
#
# Execution Summary
# =================
# RunId: soda_cans_1551993763_a5d18168
# {'runId': 'soda_cans_1551993763_a5d18168',
#  'target': 'cpucluster1',
#  'status': 'Completed',
#  'startTimeUtc': '2019-03-07T21:35:29.463134Z',
#  'endTimeUtc': '2019-03-07T21:43:49.985596Z',
#  'properties': {'azureml.runsource': 'experiment',
#   'ContentSnapshotId': '0be5d6ef-4c39-476c-aa3b-64d74aeeae52'},
#  'runDefinition': {'Script': 'retrain.py',
#   'Arguments': ['--image_dir',
#    '$AZUREML_DATAREFERENCE_workspaceblobstore',
#    '--architecture',
#    'mobilenet_1.0_224',
#    '--output_graph',
#    'outputs/retrained_graph.pb',
#    '--output_labels',
#    'outputs/output_labels.txt',
#    '--model_download_url',
#    'https://raw.githubusercontent.com/rakelkar/models/master/model_output/',
#    '--model_file_name',
#    'imagenet_2_frozen.pb'],
#   'SourceDirectoryDataStore': None,
#   'Framework': 0,
#   'Communicator': 0,
#   'Target': 'cpucluster1',
#   'DataReferences': {'workspaceblobstore': {'DataStoreName': 'workspaceblobstore',
#     'Mode': 'Download',
#     'PathOnDataStore': 'soda_cans_training_data',
#     'PathOnCompute': None,
#     'Overwrite': True}},
#   'JobName': None,
#   'AutoPrepareEnvironment': True,
#   'MaxRunDurationSeconds': None,
#   'NodeCount': 1,
#   'Environment': {'Python': {'InterpreterPath': 'python',
#     'UserManagedDependencies': False,
#     'CondaDependencies': {'name': 'project_environment',
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-defaults==1.0.17']},
#       'tensorflow==1.8.0']}},
#    'EnvironmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'Docker': {'BaseImage': 'mcr.microsoft.com/azureml/base:0.2.2',
#     'Enabled': True,
#     'SharedVolumes': True,
#     'Preparation': None,
#     'GpuSupport': False,
#     'ShmSize': '1g',
#     'Arguments': [],
#     'BaseImageRegistry': {'Address': None,
#      'Username': None,
#      'Password': None}},
#    'Spark': {'Repositories': ['https://mmlspark.azureedge.net/maven'],
#     'Packages': [{'Group': 'com.microsoft.ml.spark',
#       'Artifact': 'mmlspark_2.11',
#       'Version': '0.12'}],
#     'PrecachePackages': True}},
#   'History': {'OutputCollection': True},
#   'Spark': {'Configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'BatchAi': {'NodeCount': 0},
#   'AmlCompute': {'Name': None,
#    'VmSize': None,
#    'VmPriority': None,
#    'RetainCluster': False,
#    'ClusterMaxNodeCount': 1},
#   'Tensorflow': {'WorkerCount': 1, 'ParameterServerCount': 1},
#   'Mpi': {'ProcessCountPerNode': 1},
#   'Hdi': {'YarnDeployMode': 2},
#   'ContainerInstance': {'Region': None, 'CpuCores': 2, 'MemoryGb': 3.5},
#   'ExposedPorts': None,
#   'PrepareEnvironment': None},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://amlvdaik14969151586.blob.core.windows.net/azureml/ExperimentRun/dcid.soda_cans_1551993763_a5d18168/azureml-logs/20_image_build_log.txt?sv=2018-03-28&sr=b&sig=swO6xnVvMv6mdtJa%2BNB7Ga%2BwVrfiEo5bNgbqWeZQLUw%3D&st=2019-03-07T21%3A33%3A53Z&se=2019-03-08T05%3A43%3A53Z&sp=r',
#   'azureml-logs/60_control_log.txt': 'https://amlvdaik14969151586.blob.core.windows.net/azureml/ExperimentRun/dcid.soda_cans_1551993763_a5d18168/azureml-logs/60_control_log.txt?sv=2018-03-28&sr=b&sig=deUJSb0DqXAVyBiEGWJJ6e8C0YBrH1h1LqT0TbXNlXU%3D&st=2019-03-07T21%3A33%3A53Z&se=2019-03-08T05%3A43%3A53Z&sp=r',
#   'azureml-logs/80_driver_log.txt': 'https://amlvdaik14969151586.blob.core.windows.net/azureml/ExperimentRun/dcid.soda_cans_1551993763_a5d18168/azureml-logs/80_driver_log.txt?sv=2018-03-28&sr=b&sig=mVjA6CBnlnSJ0bbisWoW8TesWRVB3ixOMe2f6aWeK74%3D&st=2019-03-07T21%3A33%3A53Z&se=2019-03-08T05%3A43%3A53Z&sp=r',
#   'azureml-logs/azureml.log': 'https://amlvdaik14969151586.blob.core.windows.net/azureml/ExperimentRun/dcid.soda_cans_1551993763_a5d18168/azureml-logs/azureml.log?sv=2018-03-28&sr=b&sig=N8fwCMqJm%2BOjTSxqrGaUhH2Cwot6VyhqGLfJZCDVQh8%3D&st=2019-03-07T21%3A33%3A53Z&se=2019-03-08T05%3A43%3A53Z&sp=r',
#   'azureml-logs/55_batchai_execution.txt': 'https://amlvdaik14969151586.blob.core.windows.net/azureml/ExperimentRun/dcid.soda_cans_1551993763_a5d18168/azureml-logs/55_batchai_execution.txt?sv=2018-03-28&sr=b&sig=ZazI%2BO9WG3EEWOzxcSsu9RW%2Bw50nFKfvD8erGSVFW8k%3D&st=2019-03-07T21%3A33%3A53Z&se=2019-03-08T05%3A43%3A53Z&sp=r'}}

# %% [markdown]
# ## Get the trained model

# %%
trained_model_path = "models/mobilenet-orig"

# %%
# Download the retrained model and the labels locally
run.download_file(name = 'outputs/retrained_graph.pb', output_file_path = trained_model_path)
run.download_file(name = 'outputs/output_labels.txt', output_file_path = trained_model_path)

# %% [markdown]
# ### VAM config file
# Engine: This is the network used by the model 0: MobileNet 1: MobileNet-SSD 2: SqueezeNet
#
# NetworkIO: 0: CPU (default) 1: DSP
#
# Runtime: this is the HW option to use for inferencing 0: CPU 1: DSP 2: GPU
#
# ConfThreshold: This is the threshold for when the bounding boxes are shown or inferencing results are shown on screen.

# %%
vam_config_file = trained_model_path + "/va-snpe-engine-library_config.json"

# %%
# %%writefile $vam_config_file
# {
# "Engine":0,
# "NetworkIO":1,
# "ScaleWidth":224,
# "ScaleHeight":224,
# "PixelNorm":127.5,
# "BlueMean":104,
# "GreenMean":117,
# "RedMean":123,
# "TargetFPS":30,
# "ConfThreshold":0.0,
# "DLC_NAME":"model.dlc",
# "LABELS_NAME":"output_labels.txt",
# "InputLayers":"input:0",
# "OutputLayers":["final_result"],
# "ResultLayers":["final_result:0"],
# "Runtime":1
# }
# Out:
# Overwriting models/mobilenet-orig/va-snpe-engine-library_config.json

# %%
from azureml.core.model import Model

model = Model.register(model_path = trained_model_path,
                      model_name = "soda_cans",
                      tags = {"data": "Imagenet", "model": "object_detection", "type": "imagenet"},
                      description = "Retrained soda cans based on MobileNet",
                      workspace = ws)
# Out:
# Registering model soda_cans

# %%
from azureml.contrib.iot.model_converters import SnpeConverter

# submit a compile request
compile_request = SnpeConverter.convert_tf_model(
    ws,
    source_model=model,
    input_node="input",
    input_dims="1,224,224,3",
    outputs_nodes = ["final_result"],
    allow_unconsumed_nodes = True)
print(compile_request._operation_id)

# %%
# wait for the request to complete
compile_request.wait_for_completion(show_output=True)

# %%
# Get converted model
converted_model = compile_request.result
print(converted_model.name, converted_model.url, converted_model.version, converted_model.id, converted_model.created_time)

# %%
from azureml.core.image import Image
from azureml.contrib.iot import IotContainerImage
print ('We will create an image for you now ...')
image_config = IotContainerImage.image_configuration(
                                 architecture="arm32v7",
                                 execution_script="main.py", 
                                 dependencies=["camera.py","iot.py","ipcprovider.py","utility.py", "frame_iterators.py"],
                                 docker_file="Dockerfile", 
                                 tags = ["mobilenet"],
                                 description = "MobileNet model retrained soda cans")
image = Image.create(name = "mobilenetsoda",
                     # this is the model object 
                     models = [converted_model],
                     image_config = image_config, 
                     workspace = ws)
image.wait_for_creation(show_output = True)

# %%
# Parameter list

# Pick a name for what you want to call the module you deploy to the camera
module_name = "visionsample"

# Resource group in Azure 
resource_group_name= ws.resource_group
iot_rg="vaidk_"+resource_group_name

# Azure region where your services will be provisioned
iot_location="eastus2"

# Azure IoT Hub name
iot_hub_name="iothub-"+ ws.get_details()["name"]

# Pick a name for your camera
iot_device_id="vadik_"+ ws.get_details()["name"]

# Pick a name for the deployment configuration
iot_deployment_id="demovaidk"

# %%
# Getting your container details
container_reg = ws.get_details()["containerRegistry"]
reg_name=container_reg.split("/")[-1]
container_url = "\"" + image.image_location + "\","
subscription_id = ws.subscription_id
print('{}'.format(image.image_location))
print('{}'.format(reg_name))
print('{}'.format(subscription_id))
from azure.mgmt.containerregistry import ContainerRegistryManagementClient
from azure.mgmt import containerregistry
client = ContainerRegistryManagementClient(ws._auth,subscription_id)
result= client.registries.list_credentials(resource_group_name, reg_name, custom_headers=None, raw=False)
username = result.username
password = result.passwords[0].value

# %% [markdown]
# ### Deployment file
# This is the deployment.json file that you will use to deploy your model.  Please see the other sample notebooks on using this file to deploy the new model you created.

# %%
file = open('./deployment-template.json')
contents = file.read()
contents = contents.replace('__MODULE_NAME', module_name)
contents = contents.replace('__REGISTRY_NAME', reg_name)
contents = contents.replace('__REGISTRY_USER_NAME', username)
contents = contents.replace('__REGISTRY_PASSWORD', password)
contents = contents.replace('__REGISTRY_IMAGE_LOCATION', image.image_location)
with open('./deployment.json', 'wt', encoding='utf-8') as output_file:
    output_file.write(contents)
