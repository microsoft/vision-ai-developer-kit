# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# # Transfer learning sample (under construction)
# * Create Workspace
# * Register Demo model
# * Build Image
# * Create Hub and Prepare for device and deploy
# * Deploy Model

# %%
# For prod
# !pip install azureml-core
# !pip install azureml-contrib-iot
# !pip install azure-mgmt-containerregistry
# Out:
# Requirement already satisfied: azureml-core in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (1.0.6)
# Requirement already satisfied: azure-mgmt-keyvault>=0.40.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.1.0)
# Requirement already satisfied: backports.tempfile in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.0)
# Requirement already satisfied: PyJWT in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.7.1)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.4.2)
# Requirement already satisfied: contextlib2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.5.5)
# Requirement already satisfied: azure-graphrbac>=0.40.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.53.0)
# Requirement already satisfied: msrest>=0.5.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.6.2)
# Requirement already satisfied: pathspec in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.5.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.7.5)
# Requirement already satisfied: docker in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (3.6.0)
# Requirement already satisfied: azure-cli-profile>=2.0.26 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.1.2)
# Requirement already satisfied: azure-mgmt-storage>=1.5.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (3.1.1)
# Requirement already satisfied: azure-mgmt-containerregistry>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.6.0)
# Requirement already satisfied: azure-storage-blob>=1.1.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.4.0)
# Requirement already satisfied: azure-storage-nspkg>=3.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (3.1.0)
# Requirement already satisfied: requests>=2.19.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.21.0)
# Requirement already satisfied: azure-mgmt-resource>=1.2.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.1.0)
# Requirement already satisfied: azure-cli-core>=2.0.38 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.0.54)
# Requirement already satisfied: jsonpickle in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.0)
# Requirement already satisfied: ndg-httpsclient in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.5.1)
# Requirement already satisfied: ruamel.yaml<=0.15.51,>=0.15.35 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.15.51)
# Requirement already satisfied: urllib3<1.24,>=1.23 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.23)
# Requirement already satisfied: six>=1.11.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.12.0)
# Requirement already satisfied: azure-common>=1.1.12 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.1.16)
# Requirement already satisfied: msrestazure>=0.4.33 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.6.0)
# Requirement already satisfied: azure-mgmt-authorization>=0.40.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.51.1)
# Requirement already satisfied: azure-storage-common>=1.1.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.4.0)
# Requirement already satisfied: SecretStorage<3.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.3.1)
# Requirement already satisfied: pytz in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2018.7)
# Requirement already satisfied: azure-mgmt-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-mgmt-keyvault>=0.40.0->azureml-core) (3.0.2)
# Requirement already satisfied: backports.weakref in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from backports.tempfile->azureml-core) (1.0.post1)
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core) (1.11.5)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core) (0.24.0)
# Requirement already satisfied: idna>=2.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core) (2.8)
# Requirement already satisfied: isodate>=0.6.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.1->azureml-core) (0.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.1->azureml-core) (2018.11.29)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.1->azureml-core) (1.0.0)
# Requirement already satisfied: pypiwin32==223; sys_platform == "win32" and python_version >= "3.6" in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from docker->azureml-core) (223)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from docker->azureml-core) (0.54.0)
# Requirement already satisfied: docker-pycreds>=0.3.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from docker->azureml-core) (0.4.0)
# Requirement already satisfied: azure-cli-command-modules-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-profile>=2.0.26->azureml-core) (2.0.2)
# Requirement already satisfied: azure-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-storage-nspkg>=3.0.0->azureml-core) (3.0.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests>=2.19.1->azureml-core) (3.0.4)
# Requirement already satisfied: knack==0.5.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (0.5.1)
# Requirement already satisfied: pygments in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (2.3.1)
# Requirement already satisfied: pip in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (18.1)
# Requirement already satisfied: argcomplete>=1.8.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (1.9.4)
# Requirement already satisfied: futures in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (3.1.1)
# Requirement already satisfied: azure-cli-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (3.0.3)
# Requirement already satisfied: adal>=1.2.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (1.2.0)
# Requirement already satisfied: colorama>=0.3.9 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (0.4.1)
# Requirement already satisfied: paramiko>=2.0.8 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (2.4.2)
# Requirement already satisfied: pyyaml~=3.13 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (3.13)
# Requirement already satisfied: antlr4-python3-runtime; python_version >= "3.0" in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (4.7.2)
# Requirement already satisfied: pyopenssl>=17.1.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (18.0.0)
# Requirement already satisfied: wheel==0.30.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (0.30.0)
# Requirement already satisfied: tabulate<=0.8.2,>=0.7.7 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (0.8.2)
# Requirement already satisfied: azure-cli-telemetry in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (1.0.0)
# Requirement already satisfied: jmespath in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (0.9.3)
# Requirement already satisfied: humanfriendly>=4.7 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (4.17)
# Requirement already satisfied: pyasn1>=0.1.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from ndg-httpsclient->azureml-core) (0.4.5)
# Requirement already satisfied: pycparser in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cffi!=1.11.3,>=1.7->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core) (2.19)
# Requirement already satisfied: oauthlib>=0.6.2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core) (2.1.0)
# Requirement already satisfied: pywin32>=223 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from pypiwin32==223; sys_platform == "win32" and python_version >= "3.6"->docker->azureml-core) (224)
# Requirement already satisfied: pynacl>=1.0.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core) (1.3.0)
# Requirement already satisfied: bcrypt>=3.1.3 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core) (3.1.5)
# Requirement already satisfied: portalocker==1.2.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-telemetry->azure-cli-core>=2.0.38->azureml-core) (1.2.1)
# Requirement already satisfied: applicationinsights>=0.11.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-telemetry->azure-cli-core>=2.0.38->azureml-core) (0.11.7)
# Requirement already satisfied: pyreadline; sys_platform == "win32" in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from humanfriendly>=4.7->azure-cli-core>=2.0.38->azureml-core) (2.1)
# Requirement already satisfied: azureml-contrib-iot in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (1.0.6)
# Requirement already satisfied: azureml-core==1.0.6.* in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-contrib-iot) (1.0.6)
# Requirement already satisfied: requests>=2.19.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.21.0)
# Requirement already satisfied: pytz in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2018.7)
# Requirement already satisfied: msrestazure>=0.4.33 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.6.0)
# Requirement already satisfied: azure-storage-common>=1.1.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.4.0)
# Requirement already satisfied: azure-storage-nspkg>=3.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (3.1.0)
# Requirement already satisfied: msrest>=0.5.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.6.2)
# Requirement already satisfied: docker in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (3.6.0)
# Requirement already satisfied: urllib3<1.24,>=1.23 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.23)
# Requirement already satisfied: pathspec in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.5.9)
# Requirement already satisfied: azure-mgmt-authorization>=0.40.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.51.1)
# Requirement already satisfied: PyJWT in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.7.1)
# Requirement already satisfied: six>=1.11.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.12.0)
# Requirement already satisfied: azure-mgmt-containerregistry>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.6.0)
# Requirement already satisfied: ndg-httpsclient in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.5.1)
# Requirement already satisfied: contextlib2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.5.5)
# Requirement already satisfied: SecretStorage<3.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.3.1)
# Requirement already satisfied: azure-mgmt-keyvault>=0.40.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.1.0)
# Requirement already satisfied: azure-storage-blob>=1.1.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.4.0)
# Requirement already satisfied: jsonpickle in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.0)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.4.2)
# Requirement already satisfied: azure-mgmt-resource>=1.2.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.1.0)
# Requirement already satisfied: azure-graphrbac>=0.40.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.53.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.7.5)
# Requirement already satisfied: azure-cli-profile>=2.0.26 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.1.2)
# Requirement already satisfied: backports.tempfile in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.0)
# Requirement already satisfied: azure-mgmt-storage>=1.5.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (3.1.1)
# Requirement already satisfied: azure-cli-core>=2.0.38 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.0.54)
# Requirement already satisfied: azure-common>=1.1.12 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.1.16)
# Requirement already satisfied: ruamel.yaml<=0.15.51,>=0.15.35 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.15.51)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests>=2.19.1->azureml-core==1.0.6.*->azureml-contrib-iot) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests>=2.19.1->azureml-core==1.0.6.*->azureml-contrib-iot) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests>=2.19.1->azureml-core==1.0.6.*->azureml-contrib-iot) (2018.11.29)
# Requirement already satisfied: adal<2.0.0,>=0.6.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrestazure>=0.4.33->azureml-core==1.0.6.*->azureml-contrib-iot) (1.2.0)
# Requirement already satisfied: azure-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-storage-nspkg>=3.0.0->azureml-core==1.0.6.*->azureml-contrib-iot) (3.0.2)
# Requirement already satisfied: isodate>=0.6.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.1->azureml-core==1.0.6.*->azureml-contrib-iot) (0.6.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.1->azureml-core==1.0.6.*->azureml-contrib-iot) (1.0.0)
# Requirement already satisfied: docker-pycreds>=0.3.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from docker->azureml-core==1.0.6.*->azureml-contrib-iot) (0.4.0)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from docker->azureml-core==1.0.6.*->azureml-contrib-iot) (0.54.0)
# Requirement already satisfied: pypiwin32==223; sys_platform == "win32" and python_version >= "3.6" in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from docker->azureml-core==1.0.6.*->azureml-contrib-iot) (223)
# Requirement already satisfied: PyOpenSSL in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from ndg-httpsclient->azureml-core==1.0.6.*->azureml-contrib-iot) (18.0.0)
# Requirement already satisfied: pyasn1>=0.1.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from ndg-httpsclient->azureml-core==1.0.6.*->azureml-contrib-iot) (0.4.5)
# Requirement already satisfied: azure-mgmt-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-mgmt-keyvault>=0.40.0->azureml-core==1.0.6.*->azureml-contrib-iot) (3.0.2)
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.6.*->azureml-contrib-iot) (1.11.5)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.6.*->azureml-contrib-iot) (0.24.0)
# Requirement already satisfied: azure-cli-command-modules-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-profile>=2.0.26->azureml-core==1.0.6.*->azureml-contrib-iot) (2.0.2)
# Requirement already satisfied: backports.weakref in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from backports.tempfile->azureml-core==1.0.6.*->azureml-contrib-iot) (1.0.post1)
# Requirement already satisfied: colorama>=0.3.9 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (0.4.1)
# Requirement already satisfied: humanfriendly>=4.7 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (4.17)
# Requirement already satisfied: azure-cli-telemetry in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (1.0.0)
# Requirement already satisfied: knack==0.5.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (0.5.1)
# Requirement already satisfied: pyyaml~=3.13 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (3.13)
# Requirement already satisfied: paramiko>=2.0.8 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (2.4.2)
# Requirement already satisfied: tabulate<=0.8.2,>=0.7.7 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (0.8.2)
# Requirement already satisfied: futures in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (3.1.1)
# Requirement already satisfied: azure-cli-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (3.0.3)
# Requirement already satisfied: wheel==0.30.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (0.30.0)
# Requirement already satisfied: argcomplete>=1.8.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (1.9.4)
# Requirement already satisfied: antlr4-python3-runtime; python_version >= "3.0" in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (4.7.2)
# Requirement already satisfied: jmespath in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (0.9.3)
# Requirement already satisfied: pygments in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (2.3.1)
# Requirement already satisfied: pip in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (18.1)
# Requirement already satisfied: oauthlib>=0.6.2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core==1.0.6.*->azureml-contrib-iot) (2.1.0)
# Requirement already satisfied: pywin32>=223 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from pypiwin32==223; sys_platform == "win32" and python_version >= "3.6"->docker->azureml-core==1.0.6.*->azureml-contrib-iot) (224)
# Requirement already satisfied: pycparser in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cffi!=1.11.3,>=1.7->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.6.*->azureml-contrib-iot) (2.19)
# Requirement already satisfied: pyreadline; sys_platform == "win32" in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from humanfriendly>=4.7->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (2.1)
# Requirement already satisfied: portalocker==1.2.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-telemetry->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (1.2.1)
# Requirement already satisfied: applicationinsights>=0.11.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-telemetry->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (0.11.7)
# Requirement already satisfied: bcrypt>=3.1.3 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (3.1.5)
# Requirement already satisfied: pynacl>=1.0.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (1.3.0)
# Requirement already satisfied: azure-mgmt-containerregistry in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (2.6.0)
# Requirement already satisfied: azure-common~=1.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-mgmt-containerregistry) (1.1.16)
# Requirement already satisfied: msrest>=0.5.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-mgmt-containerregistry) (0.6.2)
# Requirement already satisfied: msrestazure<2.0.0,>=0.4.32 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-mgmt-containerregistry) (0.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.0->azure-mgmt-containerregistry) (2018.11.29)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.0->azure-mgmt-containerregistry) (1.0.0)
# Requirement already satisfied: requests~=2.16 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.0->azure-mgmt-containerregistry) (2.21.0)
# Requirement already satisfied: isodate>=0.6.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.0->azure-mgmt-containerregistry) (0.6.0)
# Requirement already satisfied: adal<2.0.0,>=0.6.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (1.2.0)
# Requirement already satisfied: oauthlib>=0.6.2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-mgmt-containerregistry) (2.1.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-mgmt-containerregistry) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-mgmt-containerregistry) (1.23)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-mgmt-containerregistry) (3.0.4)
# Requirement already satisfied: six in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from isodate>=0.6.0->msrest>=0.5.0->azure-mgmt-containerregistry) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.1.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (2.7.5)
# Requirement already satisfied: cryptography>=1.1.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (2.4.2)
# Requirement already satisfied: PyJWT>=1.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (1.7.1)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (0.24.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (1.11.5)
# Requirement already satisfied: pycparser in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cffi!=1.11.3,>=1.7->cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (2.19)

# %%
import os
print(os.__file__)
# Out:
# C:\ProgramData\Miniconda3\envs\vdaik1\lib\os.py

# %%
# Check core SDK version number
import azureml.core as azcore

print("SDK version:", azcore.VERSION)
# Out:
# SDK version: 1.0.6

# %% [markdown]
# ### Create a Workspace
# #### Change this cell from markdown to code and run this if you need to create a workspace
# #### Update the values for your workspace below
# ws=Workspace.create(subscription_id="replace-with-subscription-id",
#                 resource_group="your-resource-group",
#                 name="your-workspace-name",
#                 location="eastus2")
#
# ws.write_config()

# %%
#Initialize Workspace 
from azureml.core import Workspace

ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# Found the config file in: C:\Users\tedway\git\azure-vision-ai-dev-kit-pr\notebooks\aml_config\config.json
# aml-vdaik-1
# tedway-vienna1-rg
# eastus2
# 75f78a03-482f-4fd8-8c71-5ddc08f92726

# %% [markdown]
# ### Create Experiment
# Experiment is a logical container in an Azure ML Workspace. It hosts run records which can include run metrics and output artifacts from your experiments.

# %%
experiment_name = 'soda_cans'

from azureml.core import Experiment
exp = Experiment(workspace = ws, name = experiment_name)

# %% [markdown]
# ## Get data
# ### Option 1: Upload data files into datastore
# Every workspace comes with a default datastore (and you can register more) which is backed by the Azure blob storage account associated with the workspace. We can use it to transfer data from local to the cloud, and access it from the compute target.

# %%
# get the default datastore
ds = ws.get_default_datastore()
print(ds.name, ds.datastore_type, ds.account_name, ds.container_name)
# Out:
# workspaceblobstore AzureBlob amlvdaik14969151586 azureml-blobstore-1721629c-c5b4-4182-940b-a0cdff79ba52

# %%
data_path = experiment_name + '_training_data'
ds.upload(src_dir='data/soda_cans', target_path=data_path, overwrite=True)
# Out:
# Uploading data/soda_cans\coke\IMG_20181207_154649.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154652.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154654.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154656.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154659.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154671.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154672.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154673.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154701.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154704.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154706.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154708.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154710.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154712.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154714.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154724.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154726.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154732.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154735.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154737.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154739.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154741.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154743.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154746.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154748.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154750.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154752.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154756.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154758.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154800.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154802.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154804.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154654.jpg, 1 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154701.jpg, 2 files out of an estimated total of 133
# Uploading data/soda_cans\coke\IMG_20181207_154805.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154806.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154656.jpg, 3 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154919.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154704.jpg, 4 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154671.jpg, 5 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154922.jpg
# Uploading data/soda_cans\duck\IMG_20181207_154925.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154673.jpg, 6 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154714.jpg, 7 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154652.jpg, 8 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154927.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154710.jpg, 9 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154929.jpg
# Uploading data/soda_cans\duck\IMG_20181207_154931.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154758.jpg, 10 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154804.jpg, 11 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154933.jpg
# Uploading data/soda_cans\duck\IMG_20181207_154936.jpg
# Uploading data/soda_cans\duck\IMG_20181207_154938.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154659.jpg, 12 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154708.jpg, 13 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154756.jpg, 14 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154940.jpg
# Uploading data/soda_cans\duck\IMG_20181207_154945.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154737.jpg, 15 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154712.jpg, 16 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154706.jpg, 17 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154947.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154800.jpg, 18 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154949.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154672.jpg, 19 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154649.jpg, 20 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154951.jpg
# Uploading data/soda_cans\duck\IMG_20181207_154953.jpg
# Uploading data/soda_cans\duck\IMG_20181207_154955.jpg
# Uploading data/soda_cans\duck\IMG_20181207_154958.jpg
# Uploading data/soda_cans\duck\IMG_20181207_154961.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154802.jpg, 21 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154962.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154743.jpg, 22 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154963.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154735.jpg, 23 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154964.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154739.jpg, 24 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154965.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154732.jpg, 25 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154966.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154741.jpg, 26 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154967.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154752.jpg, 27 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154968.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154748.jpg, 28 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154969.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154724.jpg, 29 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154970.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154746.jpg, 30 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154971.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154919.jpg, 31 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154991.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154726.jpg, 32 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154992.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154922.jpg, 33 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154993.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154933.jpg, 34 files out of an estimated total of 133
# Uploaded data/soda_cans\duck\IMG_20181207_154925.jpg, 35 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_155000.jpg
# Uploading data/soda_cans\duck\IMG_20181207_155002.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154931.jpg, 36 files out of an estimated total of 133
# Uploaded data/soda_cans\duck\IMG_20181207_154927.jpg, 37 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154349.jpg
# Uploading data/soda_cans\ice\IMG_20181207_154350.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154938.jpg, 38 files out of an estimated total of 133
# Uploaded data/soda_cans\duck\IMG_20181207_154961.jpg, 39 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154357.jpg
# Uploading data/soda_cans\ice\IMG_20181207_154358.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154940.jpg, 40 files out of an estimated total of 133
# Uploaded data/soda_cans\duck\IMG_20181207_154962.jpg, 41 files out of an estimated total of 133
# Uploaded data/soda_cans\duck\IMG_20181207_154929.jpg, 42 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154361.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154963.jpg, 43 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154362.jpg
# Uploading data/soda_cans\ice\IMG_20181207_154363.jpg
# Uploading data/soda_cans\ice\IMG_20181207_154364.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154964.jpg, 44 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154365.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154965.jpg, 45 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154367.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154966.jpg, 46 files out of an estimated total of 133
# Uploaded data/soda_cans\duck\IMG_20181207_154967.jpg, 47 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154375.jpg
# Uploading data/soda_cans\ice\IMG_20181207_154376.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154805.jpg, 48 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154377.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154969.jpg, 49 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154378.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154971.jpg, 50 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154391.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154970.jpg, 51 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154392.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154951.jpg, 52 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154393.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154806.jpg, 53 files out of an estimated total of 133
# Uploaded data/soda_cans\duck\IMG_20181207_154945.jpg, 54 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154400.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154947.jpg, 55 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154401.jpg
# Uploading data/soda_cans\ice\IMG_20181207_154408.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154953.jpg, 56 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154418.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154955.jpg, 57 files out of an estimated total of 133
# Uploaded data/soda_cans\duck\IMG_20181207_154991.jpg, 58 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154512.jpg
# Uploading data/soda_cans\ice\IMG_20181207_154514.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154949.jpg, 59 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154522.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154936.jpg, 60 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154524.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154958.jpg, 61 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154525.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154968.jpg, 62 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154527.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154993.jpg, 63 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154828.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154357.jpg, 64 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154830.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154376.jpg, 65 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154832.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154377.jpg, 66 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154833.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154375.jpg, 67 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154835.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154992.jpg, 68 files out of an estimated total of 133
# Uploading data/soda_cans\ice\IMG_20181207_154837.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154378.jpg, 69 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154255.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154408.jpg, 70 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154300.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154418.jpg, 71 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154307.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154512.jpg, 72 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154321.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154349.jpg, 73 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154324.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154358.jpg, 74 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154327.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154365.jpg, 75 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154330.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_155000.jpg, 76 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154331.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154522.jpg, 77 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154334.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154363.jpg, 78 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154335.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154362.jpg, 79 files out of an estimated total of 133
# Uploaded data/soda_cans\ice\IMG_20181207_154361.jpg, 80 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154337.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154524.jpg, 81 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154338.jpg
# Uploading data/soda_cans\pepsi\IMG_20181207_154339.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154350.jpg, 82 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154340.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154367.jpg, 83 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154341.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_155002.jpg, 84 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154391.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154364.jpg, 85 files out of an estimated total of 133
# Uploaded data/soda_cans\ice\IMG_20181207_154828.jpg, 86 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154392.jpg
# Uploading data/soda_cans\pepsi\IMG_20181207_154393.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154391.jpg, 87 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154539.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154393.jpg, 88 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154542.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154401.jpg, 89 files out of an estimated total of 133
# Uploaded data/soda_cans\ice\IMG_20181207_154392.jpg, 90 files out of an estimated total of 133
# Uploaded data/soda_cans\ice\IMG_20181207_154400.jpg, 91 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154545.jpg
# Uploading data/soda_cans\pepsi\IMG_20181207_154546.jpg
# Uploading data/soda_cans\pepsi\IMG_20181207_154551.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154830.jpg, 92 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154552.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154514.jpg, 93 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154553.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154837.jpg, 94 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154555.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154525.jpg, 95 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154556.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154832.jpg, 96 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154812.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154835.jpg, 97 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154814.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154527.jpg, 98 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154815.jpg
# Uploaded data/soda_cans\pepsi\IMG_20181207_154307.jpg, 99 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154817.jpg
# Uploaded data/soda_cans\pepsi\IMG_20181207_154321.jpg, 100 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154818.jpg
# Uploaded data/soda_cans\pepsi\IMG_20181207_154300.jpg, 101 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154820.jpg
# Uploaded data/soda_cans\pepsi\IMG_20181207_154324.jpg, 102 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154330.jpg, 103 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154327.jpg, 104 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154331.jpg, 105 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154339.jpg, 106 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154340.jpg, 107 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154337.jpg, 108 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154341.jpg, 109 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154334.jpg, 110 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154338.jpg, 111 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154255.jpg, 112 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154392.jpg, 113 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154393.jpg, 114 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154391.jpg, 115 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154545.jpg, 116 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154555.jpg, 117 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154556.jpg, 118 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154539.jpg, 119 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154817.jpg, 120 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154818.jpg, 121 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154335.jpg, 122 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154815.jpg, 123 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154553.jpg, 124 files out of an estimated total of 133
# Uploaded data/soda_cans\ice\IMG_20181207_154833.jpg, 125 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154542.jpg, 126 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154812.jpg, 127 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154814.jpg, 128 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154546.jpg, 129 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154551.jpg, 130 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154820.jpg, 131 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154552.jpg, 132 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154750.jpg, 133 files out of an estimated total of 133
# $AZUREML_DATAREFERENCE_282d45a275df46ba95be8c1412991adf

# %% [markdown]
# ### Option 2: Use existing datastore in Azure blob storage

# %%
from azureml.core.datastore import Datastore
ds = Datastore.register_azure_blob_container(workspace=ws, 
                                         datastore_name='amlvdaik14969151586', 
                                         container_name='azureml-blobstore-1721629c-c5b4-4182-940b-a0cdff79ba52',
                                         account_name='amlvdaik14969151586', 
                                         account_key='h3nlK9lc3OGFzCxWx8gs2Anxpsx5WoBfqV25hRtKHtTyivXkGJZ9/jNjmUcTeN6WPAeXYZlA1me/NhOeLXyCAg==',
                                         create_if_not_exists=False)
data_path = "soda_cans_training_data" # This is the path to the folder in the blob container. Set this to None to get all the contents.
print(ds.name, ds.datastore_type, ds.account_name, ds.container_name)

# %% [markdown]
# ### Configure for using ACI
# Linux-based ACI is available in West US, East US, West Europe, North Europe, West US 2, Southeast Asia, Australia East, East US 2, and Central US regions.  See details [here](https://docs.microsoft.com/en-us/azure/container-instances/container-instances-quotas#region-availability)

# %%
from azureml.core.runconfig import DataReferenceConfiguration
dr = DataReferenceConfiguration(datastore_name=ds.name, 
                   path_on_datastore=data_path, 
                   mode='download', # download files from datastore to compute target
                   overwrite=True)

# %% [markdown]
# Set the system to build a conda environment based on the run configuration. Once the environment is built, and if you don't change your dependencies, it will be reused in subsequent runs.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# choose a name for your cluster
cluster_name = "cpucluster1"

try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing compute target.')
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_D3', max_nodes=2)

    # create the cluster
    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

    compute_target.wait_for_completion(show_output=True)

# Use the 'status' property to get a detailed status for the current AmlCompute. 
print(compute_target.status.serialize())
# Out:
# Found existing compute target.
# {'allocationState': 'Steady', 'allocationStateTransitionTime': '2019-01-30T00:26:57.537000+00:00', 'creationTime': '2019-01-09T23:59:06.540668+00:00', 'currentNodeCount': 0, 'errors': None, 'modifiedTime': '2019-01-09T23:59:44.897457+00:00', 'nodeStateCounts': {'idleNodeCount': 0, 'leavingNodeCount': 0, 'preemptedNodeCount': 0, 'preparingNodeCount': 0, 'runningNodeCount': 0, 'unusableNodeCount': 0}, 'provisioningState': 'Succeeded', 'provisioningStateTransitionTime': None, 'scaleSettings': {'minNodeCount': 0, 'maxNodeCount': 2, 'nodeIdleTimeBeforeScaleDown': 'PT120S'}, 'targetNodeCount': 0, 'vmPriority': 'Dedicated', 'vmSize': 'STANDARD_D3'}

# %%
from azureml.core.runconfig import RunConfiguration, DEFAULT_CPU_IMAGE
from azureml.core.conda_dependencies import CondaDependencies

# create a new runconfig object
run_config = RunConfiguration(framework = "python")

# Set compute target
run_config.target = compute_target.name

# set the data reference of the run configuration
run_config.data_references = {ds.name: dr}

# enable Docker 
run_config.environment.docker.enabled = True

# set Docker base image to the default CPU-based image
run_config.environment.docker.base_image = DEFAULT_CPU_IMAGE

# use conda_dependencies.yml to create a conda environment in the Docker image for execution
run_config.environment.python.user_managed_dependencies = False

# auto-prepare the Docker image when used for execution (if it is not already prepared)
run_config.auto_prepare_environment = True

# specify CondaDependencies obj
run_config.environment.python.conda_dependencies = CondaDependencies.create(conda_packages=['tensorflow==1.8.0'])

# %% [markdown]
# from azureml.core.runconfig import RunConfiguration
#
# # create a new runconfig object
# run_config = RunConfiguration.load('.', 'aci')
# run_config.target = compute_target.name
#
# # set the data reference of the run configuration
# run_config.data_references = {ds.name: dr}

# %% [markdown]
# ### Submit the Experiment
# Submit script to run in the Docker image in the remote VM. If you run this for the first time, the system will download the base image, layer in packages specified in the conda_dependencies.yml file on top of the base image, create a container and then execute the script in the container.

# %%
from azureml.core import Run
from azureml.core import ScriptRunConfig

src = ScriptRunConfig(source_directory = './02-mobilenet-transfer-learning-scripts', script = 'retrain.py', run_config = run_config, 
                      # pass the datastore reference as a parameter to the training script
                      arguments=['--image_dir', str(ds.as_download()),
                                 '--architecture', 'mobilenet_1.0_224',
                                 '--output_graph', 'outputs/retrained_graph.pb',
                                 '--output_labels', 'outputs/output_labels.txt',
                                 '--model_download_url', 'https://raw.githubusercontent.com/rakelkar/models/master/model_output/',
                                 '--model_file_name', 'imagenet_2_frozen.pb'
                                ])
run = exp.submit(config=src)

# %%
run
# Out:
# Run(Experiment: soda_cans,
# Id: soda_cans_1548979458368,
# Type: azureml.scriptrun,
# Status: Preparing)

# %%
run.wait_for_completion(show_output=True)
# Out:
# RunId: soda_cans_1548979458368
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2019/02/01 00:04:25 Using acb_vol_7a950a2d-2b74-42b6-9623-b101bffb41d3 as the home volume
# 2019/02/01 00:04:25 Creating Docker network: acb_default_network, driver: 'bridge'
# 2019/02/01 00:04:25 Successfully set up Docker network: acb_default_network
# 2019/02/01 00:04:25 Setting up Docker configuration...
# 2019/02/01 00:04:26 Successfully set up Docker configuration
# 2019/02/01 00:04:26 Logging in to registry: amlvdaik10491222845.azurecr.io
# 2019/02/01 00:04:28 Successfully logged into amlvdaik10491222845.azurecr.io
# 2019/02/01 00:04:28 Executing step ID: acb_step_0. Working directory: '', Network: 'acb_default_network'
# 2019/02/01 00:04:28 Obtaining source code and scanning for dependencies...
# 2019/02/01 00:04:28 Successfully obtained source code and scanned for dependencies
# 2019/02/01 00:04:28 Launching container with name: acb_step_0
# Sending build context to Docker daemon  40.96kB
#
# Step 1/13 : FROM mcr.microsoft.com/azureml/base:0.2.0
# 0.2.0: Pulling from azureml/base
# 3b37166ec614: Pulling fs layer
# 504facff238f: Pulling fs layer
# ebbcacd28e10: Pulling fs layer
# c7fb3351ecad: Pulling fs layer
# 2e3debadcbf7: Pulling fs layer
# 7ff5eaad8a49: Pulling fs layer
# 8697dd9e92dc: Pulling fs layer
# 112403772eb3: Pulling fs layer
# 0431a9485aa5: Pulling fs layer
# a8ab5d81aeba: Pulling fs layer
# c7fb3351ecad: Waiting
# 2e3debadcbf7: Waiting
# 7ff5eaad8a49: Waiting
# 8697dd9e92dc: Waiting
# 112403772eb3: Waiting
# 0431a9485aa5: Waiting
# a8ab5d81aeba: Waiting
# 504facff238f: Download complete
# ebbcacd28e10: Verifying Checksum
# ebbcacd28e10: Download complete
# 2e3debadcbf7: Download complete
# c7fb3351ecad: Verifying Checksum
# c7fb3351ecad: Download complete
# 7ff5eaad8a49: Verifying Checksum
# 7ff5eaad8a49: Download complete
# 3b37166ec614: Verifying Checksum
# 3b37166ec614: Download complete
# 8697dd9e92dc: Verifying Checksum
# 8697dd9e92dc: Download complete
# 0431a9485aa5: Verifying Checksum
# 0431a9485aa5: Download complete
# a8ab5d81aeba: Verifying Checksum
# a8ab5d81aeba: Download complete
# 112403772eb3: Verifying Checksum
# 112403772eb3: Download complete
# 3b37166ec614: Pull complete
# 504facff238f: Pull complete
# ebbcacd28e10: Pull complete
# c7fb3351ecad: Pull complete
# 2e3debadcbf7: Pull complete
# 7ff5eaad8a49: Pull complete
# 8697dd9e92dc: Pull complete
# 112403772eb3: Pull complete
# 0431a9485aa5: Pull complete
# a8ab5d81aeba: Pull complete
# Digest: sha256:bddfac8e9a4406c13f314cefefa24f3f67e959a8d8b26067096f7ade6f02ef12
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:0.2.0
#  ---> b588362a9d48
# Step 2/13 : USER root
#  ---> Running in 9281d72bfba7
# Removing intermediate container 9281d72bfba7
#  ---> ff4999379cdf
# Step 3/13 : RUN mkdir -p $HOME/.cache
#  ---> Running in 31b4cb8d38ad
# Removing intermediate container 31b4cb8d38ad
#  ---> 5a72166b88b2
# Step 4/13 : WORKDIR /
#  ---> Running in 67444a006fb3
# Removing intermediate container 67444a006fb3
#  ---> 05c3fcf3006b
# Step 5/13 : COPY azureml-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 6a5c856cb87c
# Step 6/13 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.0; then conda install conda==4.4.11; fi
#  ---> Running in d25f4543c0f8
# Removing intermediate container d25f4543c0f8
#  ---> ccc04b258f8b
# Step 7/13 : COPY azureml-setup/mutated_conda_dependencies.yml azureml-setup/mutated_conda_dependencies.yml
#  ---> d7bb2430cf84
# Step 8/13 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_458e7d0ba2d1119dba603e43a612d8c1 -f azureml-setup/mutated_conda_dependencies.yml && ldconfig
#  ---> Running in 4b0e38cc96d5
# Solving environment: ...working... done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.6.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# mkl-2019.1           | 204.6 MB  |            |   0%
# mkl-2019.1           | 204.6 MB  | 1          |   2%
# mkl-2019.1           | 204.6 MB  | 4          |   5%
# mkl-2019.1           | 204.6 MB  | 7          |   8%
# mkl-2019.1           | 204.6 MB  | #1         |  11%
# mkl-2019.1           | 204.6 MB  | #4         |  15%
# mkl-2019.1           | 204.6 MB  | #8         |  18%
# mkl-2019.1           | 204.6 MB  | ##1        |  22%
# mkl-2019.1           | 204.6 MB  | ##5        |  25%
# mkl-2019.1           | 204.6 MB  | ##8        |  29%
# mkl-2019.1           | 204.6 MB  | ###2       |  32%
# mkl-2019.1           | 204.6 MB  | ###5       |  36%
# mkl-2019.1           | 204.6 MB  | ###8       |  39%
# mkl-2019.1           | 204.6 MB  | ####2      |  42%
# mkl-2019.1           | 204.6 MB  | ####5      |  46%
# mkl-2019.1           | 204.6 MB  | ####9      |  49%
# mkl-2019.1           | 204.6 MB  | #####2     |  53%
# mkl-2019.1           | 204.6 MB  | #####6     |  56%
# mkl-2019.1           | 204.6 MB  | #####9     |  59%
# mkl-2019.1           | 204.6 MB  | ######2    |  63%
# mkl-2019.1           | 204.6 MB  | ######5    |  66%
# mkl-2019.1           | 204.6 MB  | ######9    |  69%
# mkl-2019.1           | 204.6 MB  | #######2   |  73%
# mkl-2019.1           | 204.6 MB  | #######5   |  76%
# mkl-2019.1           | 204.6 MB  | #######8   |  78%
# mkl-2019.1           | 204.6 MB  | #######9   |  80%
# mkl-2019.1           | 204.6 MB  | ########1  |  81%
# mkl-2019.1           | 204.6 MB  | ########1  |  82%
# mkl-2019.1           | 204.6 MB  | ########2  |  83%
# mkl-2019.1           | 204.6 MB  | ########3  |  83%
# mkl-2019.1           | 204.6 MB  | ########3  |  83%
# mkl-2019.1           | 204.6 MB  | ########3  |  84%
# mkl-2019.1           | 204.6 MB  | ########3  |  84%
# mkl-2019.1           | 204.6 MB  | ########3  |  84%
# mkl-2019.1           | 204.6 MB  | ########4  |  84%
# mkl-2019.1           | 204.6 MB  | ########4  |  84%
# mkl-2019.1           | 204.6 MB  | ########4  |  84%
# mkl-2019.1           | 204.6 MB  | ########4  |  84%
# mkl-2019.1           | 204.6 MB  | ########4  |  84%
# mkl-2019.1           | 204.6 MB  | ########4  |  85%
# mkl-2019.1           | 204.6 MB  | ########4  |  85%
# mkl-2019.1           | 204.6 MB  | ########4  |  85%
# mkl-2019.1           | 204.6 MB  | ########4  |  85%
# mkl-2019.1           | 204.6 MB  | ########4  |  85%
# mkl-2019.1           | 204.6 MB  | ########4  |  85%
# mkl-2019.1           | 204.6 MB  | ########4  |  85%
# mkl-2019.1           | 204.6 MB  | ########4  |  85%
# mkl-2019.1           | 204.6 MB  | ########5  |  85%
# mkl-2019.1           | 204.6 MB  | ########5  |  85%
# mkl-2019.1           | 204.6 MB  | ########5  |  85%
# mkl-2019.1           | 204.6 MB  | ########5  |  85%
# mkl-2019.1           | 204.6 MB  | ########5  |  85%
# mkl-2019.1           | 204.6 MB  | ########5  |  85%
# mkl-2019.1           | 204.6 MB  | ########5  |  85%
# mkl-2019.1           | 204.6 MB  | ########5  |  86%
# mkl-2019.1           | 204.6 MB  | ########5  |  86%
# mkl-2019.1           | 204.6 MB  | ########5  |  86%
# mkl-2019.1           | 204.6 MB  | ########5  |  86%
# mkl-2019.1           | 204.6 MB  | ########5  |  86%
# mkl-2019.1           | 204.6 MB  | ########5  |  86%
# mkl-2019.1           | 204.6 MB  | ########5  |  86%
# mkl-2019.1           | 204.6 MB  | ########5  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | ########## | 100%
#
# grpcio-1.14.1        | 1.0 MB    |            |   0%
# grpcio-1.14.1        | 1.0 MB    | ########   |  80%
# grpcio-1.14.1        | 1.0 MB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########1  |  81%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# readline-7.0         | 1.1 MB    |            |   0%
# readline-7.0         | 1.1 MB    | 6          |   6%
# readline-7.0         | 1.1 MB    | ######6    |  67%
# readline-7.0         | 1.1 MB    | ########5  |  85%
# readline-7.0         | 1.1 MB    | ########## | 100%
#
# gast-0.2.2           | 138 KB    |            |   0%
# gast-0.2.2           | 138 KB    | ########## | 100%
#
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    | #######6   |  77%
# tk-8.6.8             | 3.1 MB    | ########6  |  87%
# tk-8.6.8             | 3.1 MB    | #########5 |  95%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
#
# six-1.12.0           | 22 KB     |            |   0%
# six-1.12.0           | 22 KB     | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# werkzeug-0.14.1      | 423 KB    |            |   0%
# werkzeug-0.14.1      | 423 KB    | ########8  |  89%
# werkzeug-0.14.1      | 423 KB    | ########## | 100%
#
# html5lib-0.9999999   | 176 KB    |            |   0%
# html5lib-0.9999999   | 176 KB    | ########## | 100%
#
# intel-openmp-2019.1  | 885 KB    |            |   0%
# intel-openmp-2019.1  | 885 KB    | ########7  |  87%
# intel-openmp-2019.1  | 885 KB    | ########## | 100%
#
# xz-5.2.4             | 366 KB    |            |   0%
# xz-5.2.4             | 366 KB    | #########4 |  95%
# xz-5.2.4             | 366 KB    | ########## | 100%
#
# termcolor-1.1.0      | 7 KB      |            |   0%
# termcolor-1.1.0      | 7 KB      | ########## | 100%
#
# tensorflow-base-1.8. | 71.9 MB   |            |   0%
# tensorflow-base-1.8. | 71.9 MB   | 6          |   7%
# tensorflow-base-1.8. | 71.9 MB   | #5         |  16%
# tensorflow-base-1.8. | 71.9 MB   | ##5        |  25%
# tensorflow-base-1.8. | 71.9 MB   | ###5       |  35%
# tensorflow-base-1.8. | 71.9 MB   | ####5      |  45%
# tensorflow-base-1.8. | 71.9 MB   | #####5     |  55%
# tensorflow-base-1.8. | 71.9 MB   | ######5    |  65%
# tensorflow-base-1.8. | 71.9 MB   | #######5   |  75%
# tensorflow-base-1.8. | 71.9 MB   | ########3  |  84%
# tensorflow-base-1.8. | 71.9 MB   | #########  |  90%
# tensorflow-base-1.8. | 71.9 MB   | #########4 |  94%
# tensorflow-base-1.8. | 71.9 MB   | #########7 |  97%
# tensorflow-base-1.8. | 71.9 MB   | #########9 | 100%
# tensorflow-base-1.8. | 71.9 MB   | ########## | 100%
#
# mkl_fft-1.0.10       | 170 KB    |            |   0%
# mkl_fft-1.0.10       | 170 KB    | ########## | 100%
#
# ca-certificates-2018 | 123 KB    |            |   0%
# ca-certificates-2018 | 123 KB    | ########## | 100%
#
# wheel-0.32.3         | 35 KB     |            |   0%
# wheel-0.32.3         | 35 KB     | ########## | 100%
#
# absl-py-0.7.0        | 156 KB    |            |   0%
# absl-py-0.7.0        | 156 KB    | ########## | 100%
#
# c-ares-1.15.0        | 98 KB     |            |   0%
# c-ares-1.15.0        | 98 KB     | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########1  |  82%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# certifi-2018.11.29   | 146 KB    |            |   0%
# certifi-2018.11.29   | 146 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# ncurses-6.0          | 920 KB    |            |   0%
# ncurses-6.0          | 920 KB    | #######9   |  79%
# ncurses-6.0          | 920 KB    | ########9  |  90%
# ncurses-6.0          | 920 KB    | #########8 |  99%
# ncurses-6.0          | 920 KB    | ########## | 100%
#
# openssl-1.0.2p       | 3.5 MB    |            |   0%
# openssl-1.0.2p       | 3.5 MB    | #######5   |  76%
# openssl-1.0.2p       | 3.5 MB    | #########2 |  93%
# openssl-1.0.2p       | 3.5 MB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# libgcc-ng-8.2.0      | 7.6 MB    |            |   0%
# libgcc-ng-8.2.0      | 7.6 MB    | #####4     |  55%
# libgcc-ng-8.2.0      | 7.6 MB    | #######6   |  77%
# libgcc-ng-8.2.0      | 7.6 MB    | #########4 |  95%
# libgcc-ng-8.2.0      | 7.6 MB    | ########## | 100%
#
# astor-0.7.1          | 43 KB     |            |   0%
# astor-0.7.1          | 43 KB     | ########## | 100%
#
# libstdcxx-ng-8.2.0   | 2.9 MB    |            |   0%
# libstdcxx-ng-8.2.0   | 2.9 MB    | #######7   |  77%
# libstdcxx-ng-8.2.0   | 2.9 MB    | ########## | 100%
#
# mkl_random-1.0.2     | 407 KB    |            |   0%
# mkl_random-1.0.2     | 407 KB    | #########4 |  94%
# mkl_random-1.0.2     | 407 KB    | ########## | 100%
#
# numpy-1.15.4         | 47 KB     |            |   0%
# numpy-1.15.4         | 47 KB     | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# markdown-3.0.1       | 107 KB    |            |   0%
# markdown-3.0.1       | 107 KB    | ########## | 100%
#
# _tflow_select-1.2.0  | 2 KB      |            |   0%
# _tflow_select-1.2.0  | 2 KB      | ########## | 100%
#
# libprotobuf-3.6.1    | 4.1 MB    |            |   0%
# libprotobuf-3.6.1    | 4.1 MB    | #######6   |  76%
# libprotobuf-3.6.1    | 4.1 MB    | #########3 |  93%
# libprotobuf-3.6.1    | 4.1 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #8         |  19%
# python-3.6.2         | 27.0 MB   | ####5      |  45%
# python-3.6.2         | 27.0 MB   | #######3   |  73%
# python-3.6.2         | 27.0 MB   | #########  |  90%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# tensorflow-1.8.0     | 3 KB      |            |   0%
# tensorflow-1.8.0     | 3 KB      | ########## | 100%
#
# setuptools-40.6.3    | 625 KB    |            |   0%
# setuptools-40.6.3    | 625 KB    | ########5  |  85%
# setuptools-40.6.3    | 625 KB    | ########## | 100%
#
# bleach-1.5.0         | 22 KB     |            |   0%
# bleach-1.5.0         | 22 KB     | ########## | 100%
#
# pip-18.1             | 1.8 MB    |            |   0%
# pip-18.1             | 1.8 MB    | #######8   |  78%
# pip-18.1             | 1.8 MB    | #########  |  90%
# pip-18.1             | 1.8 MB    | ########## | 100%
#
# numpy-base-1.15.4    | 4.3 MB    |            |   0%
# numpy-base-1.15.4    | 4.3 MB    | #######6   |  76%
# numpy-base-1.15.4    | 4.3 MB    | ########8  |  89%
# numpy-base-1.15.4    | 4.3 MB    | #########8 |  99%
# numpy-base-1.15.4    | 4.3 MB    | ########## | 100%
#
# tensorboard-1.8.0    | 3.1 MB    |            |   0%
# tensorboard-1.8.0    | 3.1 MB    | #######6   |  77%
# tensorboard-1.8.0    | 3.1 MB    | ########9  |  90%
# tensorboard-1.8.0    | 3.1 MB    | ########## | 100%
#
# protobuf-3.6.1       | 616 KB    |            |   0%
# protobuf-3.6.1       | 616 KB    | #######9   |  80%
# protobuf-3.6.1       | 616 KB    | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting azureml-defaults==1.0.6 (from -r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a4/97/52adc0852a11c5017ab3b3c1c852d8f82163e69f3a97cf0d71dc7811427e/azureml_defaults-1.0.6-py2.py3-none-any.whl
# Collecting applicationinsights>=0.11.7 (from azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e3/c8/7848a0dd85158930b859eb8be1e38fc76a91f0a040d491723ebb356d7358/applicationinsights-0.11.7-py2.py3-none-any.whl (56kB)
# Collecting azureml-core==1.0.6.* (from azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e9/6c/e15677f2e09c34799a61b6146418f93402c93913f538c64665ff69371e64/azureml_core-1.0.6-py2.py3-none-any.whl (658kB)
# Collecting ndg-httpsclient (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Collecting azure-mgmt-authorization>=0.40.0 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a1/71/9a20913e92771b3c23564f1bea54d376d09fb30a75585087c70b769d75c8/azure_mgmt_authorization-0.51.1-py2.py3-none-any.whl (111kB)
# Collecting contextlib2 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a2/71/8273a7eeed0aff6a854237ab5453bc9aa67deb49df4832801c21f0ff3782/contextlib2-0.5.5-py2.py3-none-any.whl
# Collecting msrestazure>=0.4.33 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/46/ba/7870308e3d3b4b3956880eed2df20669a5690436793e6fc1442c8b73e01c/msrestazure-0.6.0-py2.py3-none-any.whl
# Collecting azure-mgmt-storage>=1.5.0 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d9/87/ab44b9d9627ff91825ba5f5a39092ebfe97a90679008609db4c479036591/azure_mgmt_storage-3.1.1-py2.py3-none-any.whl (696kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/98/71/e632e222f34632e0527dd41799f7847305e701f38f512d81bdf96009bca4/cryptography-2.5-cp34-abi3-manylinux1_x86_64.whl (2.4MB)
# Collecting azure-graphrbac>=0.40.0 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/da/a8/3d3d6fe8458b2b07bad10195c79928ea9ba87b5cc0c08903b387dd27c6f0/azure_graphrbac-0.53.0-py2.py3-none-any.whl (108kB)
# Collecting azure-cli-profile>=2.0.26 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/24/82/6ca19db7bffd0d1348b5964dc885c643c61efdaff8bffd2a9b8493753e9e/azure_cli_profile-2.1.3-py2.py3-none-any.whl
# Collecting azure-common>=1.1.12 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c3/f8/46248b201fd38b7e93c6da644e2fc3bc5a39118f253562751fd295a8cc77/azure_common-1.1.18-py2.py3-none-any.whl
# Collecting pathspec (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/84/2a/bfee636b1e2f7d6e30dd74f49201ccfa5c3cf322d44929ecc6c137c486c5/pathspec-0.5.9.tar.gz
# Collecting python-dateutil>=2.7.3 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/74/68/d87d9b36af36f44254a8d512cbfc48369103a3b9e474be9bdfe536abfc45/python_dateutil-2.7.5-py2.py3-none-any.whl (225kB)
# Collecting ruamel.yaml<=0.15.51,>=0.15.35 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d2/7f/9bb3ba89ceab600c4a0ea75d638ea945215ca3458ac6528e0e39fa3254e4/ruamel.yaml-0.15.51-cp36-cp36m-manylinux1_x86_64.whl (640kB)
# Collecting azure-storage-common>=1.1.0 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/73/84/025ac436a6a1d5516d1a67887d7122b3b2ea04ba6b2d2c46fe949accb62b/azure_storage_common-1.4.0-py2.py3-none-any.whl (46kB)
# Collecting azure-cli-core>=2.0.38 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/7d/01/0613fb0e1e4cc193509bf4943047b4b028641eaa2c87193b586cf71c89e6/azure_cli_core-2.0.57-py2.py3-none-any.whl (108kB)
# Collecting pytz (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/61/28/1d3920e4d1d50b19bc5d24398a7cd85cc7b9a75a490570d5a30c57622d34/pytz-2018.9-py2.py3-none-any.whl (510kB)
# Collecting azure-mgmt-keyvault>=0.40.0 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/49/de/0d69aedae7c5f6428314640b65947203ab80409c12b5d4e66fb5b7a4182e/azure_mgmt_keyvault-1.1.0-py2.py3-none-any.whl (111kB)
# Collecting azure-storage-blob>=1.1.0 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/f7/b7/9b20c39bf411e896d110d01f2551e6e7b397fde6eb06b07293fe29705d13/azure_storage_blob-1.4.0-py2.py3-none-any.whl (75kB)
# Collecting urllib3<1.24,>=1.23 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/bd/c9/6fdd990019071a4a32a5e7cb78a1d92c53851ef4f56f62a3486e6a7d8ffb/urllib3-1.23-py2.py3-none-any.whl (133kB)
# Collecting jsonpickle (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/dc/12/8c44eabb501e2bc0aec0dd152b328074d98a50968d3a02be28f6037f0c6a/jsonpickle-1.1-py2.py3-none-any.whl
# Collecting msrest>=0.5.1 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/eb/96/1cf56e4cfd221b7f6eb6ab096dc23b0d21361393f0784276531e49b0b2a1/msrest-0.6.4-py2.py3-none-any.whl (81kB)
# Collecting docker (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/7e/3c/b610f22b170b0f8fe4d8f78974878e116562389f666f99e6549567eb9d87/docker-3.7.0-py2.py3-none-any.whl (133kB)
# Collecting azure-storage-nspkg>=3.0.0 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ba/f6/054ace7b01c6c21b3b95a83c3997f7d6539d939a2c08c4f27f779128a030/azure_storage_nspkg-3.1.0-py2.py3-none-any.whl
# Collecting PyJWT (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Collecting requests>=2.19.1 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/7d/e3/20f3d364d6c8e5d2353c72a67778eb189176f08e873c9900e10c0287b84b/requests-2.21.0-py2.py3-none-any.whl (57kB)
# Collecting SecretStorage<3.0.0 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a5/a5/0830cfe34a4cfd0d1c3c8b614ede1edb2aaf999091ac8548dd19cb352e79/SecretStorage-2.3.1.tar.gz
# Collecting azure-mgmt-containerregistry>=2.0.0 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/4e/93/982bdd8f38379405beab963ee2abf1ab42a826a57cc2157228216cfc62e4/azure_mgmt_containerregistry-2.6.0-py2.py3-none-any.whl (501kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_458e7d0ba2d1119dba603e43a612d8c1/lib/python3.6/site-packages (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1)) (1.12.0)
# Collecting azure-mgmt-resource>=1.2.1 (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/2b/2e/e79a278bedfc21308ab0c632759cfda5d7ff02d62260bcc4632449937dcf/azure_mgmt_resource-2.1.0-py2.py3-none-any.whl (757kB)
# Collecting backports.tempfile (from azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b4/5c/077f910632476281428fe254807952eb47ca78e720d059a46178c541e669/backports.tempfile-1.0-py2.py3-none-any.whl
# Collecting PyOpenSSL (from ndg-httpsclient->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/01/c8/ceb170d81bd3941cbeb9940fc6cc2ef2ca4288d0ca8929ea4db5905d904d/pyOpenSSL-19.0.0-py2.py3-none-any.whl (53kB)
# Collecting pyasn1>=0.1.1 (from ndg-httpsclient->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/7b/7c/c9386b82a25115cccf1903441bba3cbadcfae7b678a20167347fa8ded34c/pyasn1-0.4.5-py2.py3-none-any.whl (73kB)
# Collecting adal<2.0.0,>=0.6.0 (from msrestazure>=0.4.33->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/00/72/53dce9e4f5d6c1aa57b8d408cb34dff1969ecbf10ab7e678f32c5e0e2397/adal-1.2.1-py2.py3-none-any.whl (52kB)
# Collecting cffi!=1.11.3,>=1.8 (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/6d/c0/47db8f624f3e4e2f3f27be03a93379d1ba16a1450a7b1aacfa0366e2c0dd/cffi-1.11.5-cp36-cp36m-manylinux1_x86_64.whl (421kB)
# Collecting asn1crypto>=0.21.0 (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ea/cd/35485615f45f30a510576f1a56d1e0a7ad7bd8ab5ed7cdc600ef7cd06222/asn1crypto-0.24.0-py2.py3-none-any.whl (101kB)
# Collecting azure-cli-command-modules-nspkg>=2.0.0 (from azure-cli-profile>=2.0.26->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e6/c9/cdeeeabc550848e2a07caa66cba28aa057d23b6feaa824ceafd32c3f2226/azure_cli_command_modules_nspkg-2.0.2-py2.py3-none-any.whl
# Collecting antlr4-python3-runtime; python_version >= "3.0" (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/29/14/8ac135ec7cc9db3f768e2d032776718c6b23f74e63543f0974b4873500b2/antlr4-python3-runtime-4.7.2.tar.gz (112kB)
# Collecting humanfriendly>=4.7 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/79/1e/13d96248e3fcaa7777b61fa889feab44865c85e524bbd667acfa0d8b66e3/humanfriendly-4.17-py2.py3-none-any.whl (72kB)
# Collecting colorama>=0.3.9 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/4f/a6/728666f39bfff1719fc94c481890b2106837da9318031f71a8424b662e12/colorama-0.4.1-py2.py3-none-any.whl
# Collecting knack==0.5.1 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/27/46/0a6d7471efcc519e392640f6933c0f644bbf602971e64797108292cb3623/knack-0.5.1-py2.py3-none-any.whl (50kB)
# Collecting pygments (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/13/e5/6d710c9cf96c31ac82657bcfb441df328b22df8564d58d0c4cd62612674c/Pygments-2.3.1-py2.py3-none-any.whl (849kB)
# Collecting pyyaml>=4.2b1 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a8/c6/a8d1555e795dbd0375c3c93b576ca13bbf139db51ea604afa19a2c35fc03/PyYAML-4.2b4.tar.gz (262kB)
# Requirement already satisfied: pip in /azureml-envs/azureml_458e7d0ba2d1119dba603e43a612d8c1/lib/python3.6/site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1)) (18.1)
# Collecting futures (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/cc/26/b61e3a4eb50653e8a7339d84eeaa46d1e93b92951978873c220ae64d0733/futures-3.1.1.tar.gz
# Collecting azure-cli-telemetry (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e0/6b/bc6faa2f578b53888e383138fd22bb04dc3aea5718292dd5543ac0898d80/azure_cli_telemetry-1.0.1-py2.py3-none-any.whl
# Collecting tabulate<=0.8.2,>=0.7.7 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/12/c2/11d6845db5edf1295bc08b2f488cf5937806586afe42936c3f34c097ebdc/tabulate-0.8.2.tar.gz (45kB)
# Collecting jmespath (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b7/31/05c8d001f7f87f0f07289a5fc0fc3832e9a57f2dbd4d3b0fee70e0d51365/jmespath-0.9.3-py2.py3-none-any.whl
# Collecting paramiko>=2.0.8 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/cf/ae/94e70d49044ccc234bfdba20114fa947d7ba6eb68a2e452d89b920e62227/paramiko-2.4.2-py2.py3-none-any.whl (193kB)
# Collecting argcomplete>=1.8.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/31/88/ba8d8684a8a27749250c66ff7c2b408fdbc29b50da61200338ff9b2607bf/argcomplete-1.9.4-py2.py3-none-any.whl
# Collecting wheel==0.30.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/0c/80/16a85b47702a1f47a63c104c91abdd0a6704ee8ae3b4ce4afc49bc39f9d9/wheel-0.30.0-py2.py3-none-any.whl (49kB)
# Collecting azure-cli-nspkg>=2.0.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a7/85/601ef6484bf7a722daa76a4383c4ccfd4980b74ed6c2895392f53ed210d5/azure_cli_nspkg-3.0.3-py2.py3-none-any.whl
# Collecting azure-mgmt-nspkg>=2.0.0 (from azure-mgmt-keyvault>=0.40.0->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b3/c2/af4b47845f27dc7d206ed4908b9e580f8bc94a4b2f3956a0d87c40719d90/azure_mgmt_nspkg-3.0.2-py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_458e7d0ba2d1119dba603e43a612d8c1/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1)) (2018.11.29)
# Collecting isodate>=0.6.0 (from msrest>=0.5.1->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.5.1->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Collecting docker-pycreds>=0.4.0 (from docker->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Collecting websocket-client>=0.32.0 (from docker->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/26/2d/f749a5c82f6192d77ed061a38e02001afcba55fe8477336d26a950ab17ce/websocket_client-0.54.0-py2.py3-none-any.whl (200kB)
# Collecting azure-nspkg>=2.0.0 (from azure-storage-nspkg>=3.0.0->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c4/0c/c562be95a9a2ed52454f598571cf300b1114d0db2aa27f5b8ed3bb9cd0c0/azure_nspkg-3.0.2-py3-none-any.whl
# Collecting idna<2.9,>=2.5 (from requests>=2.19.1->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
# Collecting chardet<3.1.0,>=3.0.2 (from requests>=2.19.1->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Collecting backports.weakref (from backports.tempfile->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Collecting pycparser (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/68/9e/49196946aee219aead1290e00d1e7fdeab8567783e83e1b9ab5585e6206a/pycparser-2.19.tar.gz (158kB)
# Collecting portalocker==1.2.1 (from azure-cli-telemetry->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/57/41/05e79e5516db1cc0c967b3202388cde729f871c871b0a07bf24ff11adfcf/portalocker-1.2.1-py2.py3-none-any.whl
# Collecting pynacl>=1.0.1 (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/27/15/2cd0a203f318c2240b42cd9dd13c931ddd61067809fee3479f44f086103e/PyNaCl-1.3.0-cp34-abi3-manylinux1_x86_64.whl (759kB)
# Collecting bcrypt>=3.1.3 (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d0/79/79a4d167a31cc206117d9b396926615fa9c1fdbd52017bcced80937ac501/bcrypt-3.1.6-cp34-abi3-manylinux1_x86_64.whl (55kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core==1.0.6.*->azureml-defaults==1.0.6->-r /azureml-setup/condaenv.wnelnaff.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/16/95/699466b05b72b94a41f662dc9edf87fda4289e3602ecd42d27fcaddf7b56/oauthlib-3.0.1-py2.py3-none-any.whl (142kB)
# ...
# INFO:tensorflow:2019-02-01 00:22:29.764773: Step 3540: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:29.765002: Step 3540: Cross entropy = 0.000270
# INFO:tensorflow:2019-02-01 00:22:29.826937: Step 3540: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:30.489406: Step 3550: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:30.489631: Step 3550: Cross entropy = 0.000192
# INFO:tensorflow:2019-02-01 00:22:30.551074: Step 3550: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:31.221461: Step 3560: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:31.221683: Step 3560: Cross entropy = 0.000216
# INFO:tensorflow:2019-02-01 00:22:31.284122: Step 3560: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:31.943235: Step 3570: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:31.943458: Step 3570: Cross entropy = 0.000330
# INFO:tensorflow:2019-02-01 00:22:32.005515: Step 3570: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:32.662899: Step 3580: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:32.663134: Step 3580: Cross entropy = 0.000304
# INFO:tensorflow:2019-02-01 00:22:32.723641: Step 3580: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:33.404743: Step 3590: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:33.404974: Step 3590: Cross entropy = 0.000255
# INFO:tensorflow:2019-02-01 00:22:33.468253: Step 3590: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:34.130233: Step 3600: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:34.130459: Step 3600: Cross entropy = 0.000230
# INFO:tensorflow:2019-02-01 00:22:34.202381: Step 3600: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:34.832090: Step 3610: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:34.832314: Step 3610: Cross entropy = 0.000202
# INFO:tensorflow:2019-02-01 00:22:34.892942: Step 3610: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:35.538176: Step 3620: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:35.538405: Step 3620: Cross entropy = 0.000407
# INFO:tensorflow:2019-02-01 00:22:35.600727: Step 3620: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:36.237550: Step 3630: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:36.237773: Step 3630: Cross entropy = 0.000267
# INFO:tensorflow:2019-02-01 00:22:36.299272: Step 3630: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:36.944825: Step 3640: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:36.945051: Step 3640: Cross entropy = 0.000152
# INFO:tensorflow:2019-02-01 00:22:37.006123: Step 3640: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:37.641421: Step 3650: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:37.641649: Step 3650: Cross entropy = 0.000359
# INFO:tensorflow:2019-02-01 00:22:37.702143: Step 3650: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:38.347285: Step 3660: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:38.347511: Step 3660: Cross entropy = 0.000224
# INFO:tensorflow:2019-02-01 00:22:38.412321: Step 3660: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:39.066895: Step 3670: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:39.067157: Step 3670: Cross entropy = 0.000242
# INFO:tensorflow:2019-02-01 00:22:39.129675: Step 3670: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:39.776924: Step 3680: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:39.777148: Step 3680: Cross entropy = 0.000212
# INFO:tensorflow:2019-02-01 00:22:39.838520: Step 3680: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:40.509778: Step 3690: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:40.510083: Step 3690: Cross entropy = 0.000190
# INFO:tensorflow:2019-02-01 00:22:40.574931: Step 3690: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:41.211222: Step 3700: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:41.211465: Step 3700: Cross entropy = 0.000277
# INFO:tensorflow:2019-02-01 00:22:41.275003: Step 3700: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:41.917241: Step 3710: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:41.917641: Step 3710: Cross entropy = 0.000358
# INFO:tensorflow:2019-02-01 00:22:41.983146: Step 3710: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:42.642265: Step 3720: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:42.642496: Step 3720: Cross entropy = 0.000210
# INFO:tensorflow:2019-02-01 00:22:42.704164: Step 3720: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:43.353613: Step 3730: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:43.353887: Step 3730: Cross entropy = 0.000278
# INFO:tensorflow:2019-02-01 00:22:43.417124: Step 3730: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:44.091536: Step 3740: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:44.091777: Step 3740: Cross entropy = 0.000287
# INFO:tensorflow:2019-02-01 00:22:44.154174: Step 3740: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:44.803453: Step 3750: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:44.803707: Step 3750: Cross entropy = 0.000300
# INFO:tensorflow:2019-02-01 00:22:44.867368: Step 3750: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:45.534326: Step 3760: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:45.534561: Step 3760: Cross entropy = 0.000308
# INFO:tensorflow:2019-02-01 00:22:45.600039: Step 3760: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:46.321635: Step 3770: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:46.321868: Step 3770: Cross entropy = 0.000213
# INFO:tensorflow:2019-02-01 00:22:46.403187: Step 3770: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:47.086088: Step 3780: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:47.086319: Step 3780: Cross entropy = 0.000135
# INFO:tensorflow:2019-02-01 00:22:47.148410: Step 3780: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:47.831660: Step 3790: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:47.831891: Step 3790: Cross entropy = 0.000309
# INFO:tensorflow:2019-02-01 00:22:47.898921: Step 3790: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:48.589280: Step 3800: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:48.589524: Step 3800: Cross entropy = 0.000193
# INFO:tensorflow:2019-02-01 00:22:48.655873: Step 3800: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:49.302769: Step 3810: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:49.303002: Step 3810: Cross entropy = 0.000195
# INFO:tensorflow:2019-02-01 00:22:49.368350: Step 3810: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:50.016629: Step 3820: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:50.016858: Step 3820: Cross entropy = 0.000217
# INFO:tensorflow:2019-02-01 00:22:50.084174: Step 3820: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:50.736132: Step 3830: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:50.736358: Step 3830: Cross entropy = 0.000301
# INFO:tensorflow:2019-02-01 00:22:50.798035: Step 3830: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:51.451357: Step 3840: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:51.451587: Step 3840: Cross entropy = 0.000285
# INFO:tensorflow:2019-02-01 00:22:51.519614: Step 3840: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:52.202376: Step 3850: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:52.202633: Step 3850: Cross entropy = 0.000224
# INFO:tensorflow:2019-02-01 00:22:52.265993: Step 3850: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:52.930127: Step 3860: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:52.930363: Step 3860: Cross entropy = 0.000199
# INFO:tensorflow:2019-02-01 00:22:52.996318: Step 3860: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:53.672712: Step 3870: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:53.672944: Step 3870: Cross entropy = 0.000276
# INFO:tensorflow:2019-02-01 00:22:53.738050: Step 3870: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:54.384290: Step 3880: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:54.384659: Step 3880: Cross entropy = 0.000208
# INFO:tensorflow:2019-02-01 00:22:54.453037: Step 3880: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:55.140637: Step 3890: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:55.140910: Step 3890: Cross entropy = 0.000347
# INFO:tensorflow:2019-02-01 00:22:55.211919: Step 3890: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:55.912902: Step 3900: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:55.913140: Step 3900: Cross entropy = 0.000291
# INFO:tensorflow:2019-02-01 00:22:55.976250: Step 3900: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:56.646174: Step 3910: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:56.646398: Step 3910: Cross entropy = 0.000309
# INFO:tensorflow:2019-02-01 00:22:56.708500: Step 3910: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:57.369740: Step 3920: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:57.370045: Step 3920: Cross entropy = 0.000208
# INFO:tensorflow:2019-02-01 00:22:57.432086: Step 3920: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:58.072819: Step 3930: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:58.073053: Step 3930: Cross entropy = 0.000168
# INFO:tensorflow:2019-02-01 00:22:58.134562: Step 3930: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:58.782542: Step 3940: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:58.782804: Step 3940: Cross entropy = 0.000188
# INFO:tensorflow:2019-02-01 00:22:58.848283: Step 3940: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:22:59.483288: Step 3950: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:22:59.483512: Step 3950: Cross entropy = 0.000360
# INFO:tensorflow:2019-02-01 00:22:59.546893: Step 3950: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:23:00.199854: Step 3960: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:23:00.200124: Step 3960: Cross entropy = 0.000215
# INFO:tensorflow:2019-02-01 00:23:00.270094: Step 3960: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:23:00.942540: Step 3970: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:23:00.942769: Step 3970: Cross entropy = 0.000211
# INFO:tensorflow:2019-02-01 00:23:01.016257: Step 3970: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:23:01.689332: Step 3980: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:23:01.689560: Step 3980: Cross entropy = 0.000266
# INFO:tensorflow:2019-02-01 00:23:01.752723: Step 3980: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:23:02.399523: Step 3990: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:23:02.399749: Step 3990: Cross entropy = 0.000195
# INFO:tensorflow:2019-02-01 00:23:02.460817: Step 3990: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-02-01 00:23:03.048464: Step 3999: Train accuracy = 100.0%
# INFO:tensorflow:2019-02-01 00:23:03.048712: Step 3999: Cross entropy = 0.000241
# INFO:tensorflow:2019-02-01 00:23:03.120953: Step 3999: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:Final test accuracy = 100.0% (N=18)
# INFO:tensorflow:Froze 2 variables.
# Converted 2 variables to const ops.
#
#
# The experiment completed successfully. Finalizing run...
# Logging experiment finalizing status in history service
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 1 items cleaning up...
# Cleanup took 0.1012732982635498 seconds
#
# Execution Summary
# =================
# RunId: soda_cans_1548979458368
# {'runId': 'soda_cans_1548979458368',
#  'target': 'cpucluster1',
#  'status': 'Finalizing',
#  'startTimeUtc': '2019-02-01T00:14:38.14264Z',
#  'properties': {'azureml.runsource': 'experiment',
#   'ContentSnapshotId': '3dd56524-8e2a-4397-b021-ba7c60810a04'},
#  'runDefinition': {'Script': 'retrain.py',
#   'Arguments': ['--image_dir',
#    '$AZUREML_DATAREFERENCE_workspaceblobstore',
#    '--architecture',
#    'mobilenet_1.0_224',
#    '--output_graph',
#    'outputs/retrained_graph.pb',
#    '--output_labels',
#    'outputs/output_labels.txt',
#    '--model_download_url',
#    'https://raw.githubusercontent.com/rakelkar/models/master/model_output/',
#    '--model_file_name',
#    'imagenet_2_frozen.pb'],
#   'SourceDirectoryDataStore': None,
#   'Framework': 0,
#   'Communicator': 0,
#   'Target': 'cpucluster1',
#   'DataReferences': {'workspaceblobstore': {'DataStoreName': 'workspaceblobstore',
#     'Mode': 'Download',
#     'PathOnDataStore': 'soda_cans_training_data',
#     'PathOnCompute': None,
#     'Overwrite': True}},
#   'JobName': None,
#   'AutoPrepareEnvironment': True,
#   'MaxRunDurationSeconds': None,
#   'NodeCount': 1,
#   'Environment': {'Python': {'InterpreterPath': 'python',
#     'UserManagedDependencies': False,
#     'CondaDependencies': {'name': 'project_environment',
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-defaults==1.0.6']},
#       'tensorflow==1.8.0']}},
#    'EnvironmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'Docker': {'BaseImage': 'mcr.microsoft.com/azureml/base:0.2.0',
#     'Enabled': True,
#     'SharedVolumes': True,
#     'Preparation': None,
#     'GpuSupport': False,
#     'ShmSize': '1g',
#     'Arguments': [],
#     'BaseImageRegistry': {'Address': None,
#      'Username': None,
#      'Password': None}},
#    'Spark': {'Repositories': ['https://mmlspark.azureedge.net/maven'],
#     'Packages': [{'Group': 'com.microsoft.ml.spark',
#       'Artifact': 'mmlspark_2.11',
#       'Version': '0.12'}],
#     'PrecachePackages': True}},
#   'History': {'OutputCollection': True},
#   'Spark': {'Configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'BatchAi': {'NodeCount': 0},
#   'AmlCompute': {'Name': None,
#    'VmSize': None,
#    'VmPriority': None,
#    'RetainCluster': False,
#    'ClusterMaxNodeCount': 1},
#   'Tensorflow': {'WorkerCount': 1, 'ParameterServerCount': 1},
#   'Mpi': {'ProcessCountPerNode': 1},
#   'Hdi': {'YarnDeployMode': 2},
#   'ContainerInstance': {'Region': None, 'CpuCores': 2, 'MemoryGb': 3.5},
#   'ExposedPorts': None,
#   'PrepareEnvironment': None},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://amlvdaik14969151586.blob.core.windows.net/azureml/ExperimentRun/dcid.soda_cans_1548979458368/azureml-logs/20_image_build_log.txt?sv=2018-03-28&sr=b&sig=h8updJpH9cwC%2FF5%2BICimNykGxHncAKO0gXWLtSMxwV8%3D&st=2019-02-01T00%3A13%3A08Z&se=2019-02-01T08%3A23%3A08Z&sp=r',
#   'azureml-logs/60_control_log.txt': 'https://amlvdaik14969151586.blob.core.windows.net/azureml/ExperimentRun/dcid.soda_cans_1548979458368/azureml-logs/60_control_log.txt?sv=2018-03-28&sr=b&sig=rHfJGaiZjAfK72sWsgd43ehJLF92FBG3sBFeRrW09cY%3D&st=2019-02-01T00%3A13%3A08Z&se=2019-02-01T08%3A23%3A08Z&sp=r',
#   'azureml-logs/80_driver_log.txt': 'https://amlvdaik14969151586.blob.core.windows.net/azureml/ExperimentRun/dcid.soda_cans_1548979458368/azureml-logs/80_driver_log.txt?sv=2018-03-28&sr=b&sig=UnrTHjf3tWkWh7xO8tv09IF1Y0HBkhgC93RChFWpHLI%3D&st=2019-02-01T00%3A13%3A08Z&se=2019-02-01T08%3A23%3A08Z&sp=r',
#   'azureml-logs/azureml.log': 'https://amlvdaik14969151586.blob.core.windows.net/azureml/ExperimentRun/dcid.soda_cans_1548979458368/azureml-logs/azureml.log?sv=2018-03-28&sr=b&sig=JUNcba6JJG9GaKl%2BItmsZnZQBV4CkYPxUqQnVh4rqvg%3D&st=2019-02-01T00%3A13%3A08Z&se=2019-02-01T08%3A23%3A08Z&sp=r'}}

# %%
# Download the retrained model and the labels locally
run.download_file(name = 'outputs/retrained_graph.pb', output_file_path = 'models/mobilenet-orig/')
run.download_file(name = 'outputs/output_labels.txt', output_file_path = 'models/mobilenet-orig/')

# %%
# Register the model by uploading the model file and label file

from azureml.core.model import Model

model = Model.register(model_path = "models/mobilenet-orig/",
                      model_name = "soda_cans",
                      tags = {"data": "Imagenet", "model": "object_classification", "type": "imagenet"},
                      description = "Retrained soda cans based on MobileNet",
                      workspace = ws)
# Out:
# Registering model soda_cans

# %%
from azureml.contrib.iot.model_converters import SnpeConverter

# submit a compile request
compile_request = SnpeConverter.convert_tf_model(
    ws,
    source_model=model,
    input_node="input",
    input_dims="1,224,224,3",
    outputs_nodes = ["final_result"],
    allow_unconsumed_nodes = True)
print(compile_request._operation_id)
# Out:
# 6a57fd06-aefb-4595-a013-74e01ff3dc2d

# %%
# wait for the request to complete
compile_request.wait_for_completion(show_output=True)
# Out:
# Running...
# Succeeded
# Operation 6a57fd06-aefb-4595-a013-74e01ff3dc2d completed, operation state "Succeeded"
# sas url to download model conversion logs https://amlvdaik14969151586.blob.core.windows.net/azureml/LocalUpload/9e6dee17614942e89760ac755dbebba8/soda_cans.15.dlc.tar.gz-userlog?sv=2018-03-28&sr=b&sig=9jgHr4lflIc5PMAyVKqRwy%2B7ERBUgpX3RgE4k806qMI%3D&st=2019-02-01T18%3A32%3A52Z&se=2019-02-02T02%3A42%3A52Z&sp=r
# [2019-02-01 18:42:35Z]: Starting model conversion process
# [2019-02-01 18:42:35Z]: Downloading model for conversion
# [2019-02-01 18:42:36Z]: Converting model
# [2019-02-01 18:42:37Z]: converter std: Executing python /snpe-1.19.2/bin/x86_64-linux-clang/snpe-tensorflow-to-dlc --graph /tmp/p2iowipd.h0g/input/retrained_graph.pb -i input 1,224,224,3 --dlc /tmp/p2iowipd.h0g/output/model.dlc --out_node final_result --allow_unconsumed_nodes in /app
# [2019-02-01 18:42:37Z]: Uploading conversion results
# [2019-02-01 18:42:39Z]: Conversion completed with result Success
# True

# %%
# Get converted model
converted_model = compile_request.result
print(converted_model.name, converted_model.url, converted_model.version, converted_model.id, converted_model.created_time)
# Out:
# soda_cans.15.dlc aml://asset/7bab897fe8544e6395a766652ac12fbc 1 soda_cans.15.dlc:1 2019-02-01 18:42:46.302811+00:00

# %%
from azureml.core.image import Image
from azureml.contrib.iot import IotContainerImage
print ('We will create an image for you now ...')
image_config = IotContainerImage.image_configuration(
                                 architecture="arm32v7",
                                 execution_script="main.py", 
                                 dependencies=["camera.py","iot.py","ipcprovider.py","utility.py", "frame_iterators.py"],
                                 docker_file="Dockerfile", 
                                 tags = ["mobilenet"],
                                 description = "MobileNet model retrained soda cans")
image = Image.create(name = "sodacans",
                     # this is the model object 
                     models = [converted_model],
                     image_config = image_config, 
                     workspace = ws)
image.wait_for_creation(show_output = True)
# Out:
# We will create an image for you now ...
# Creating image
# Running........................................................................................................................
# SucceededImage creation operation finished for image sodacans:1, operation "Succeeded"

# %%
# Parameter list

# Pick a name for what you want to call the module you deploy to the camera
module_name = "visionsample"

# Resource group in Azure 
resource_group_name= ws.resource_group
iot_rg="vaidk_"+resource_group_name

# Azure region where your services will be provisioned
iot_location="eastus2"

# Azure IoT Hub name
iot_hub_name="iothub-"+ ws.get_details()["name"]

# Pick a name for your camera
iot_device_id="vadik_"+ ws.get_details()["name"]

# Pick a name for the deployment configuration
iot_deployment_id="demovaidk"

# %%
# Getting your container details
container_reg = ws.get_details()["containerRegistry"]
reg_name=container_reg.split("/")[-1]
container_url = "\"" + image.image_location + "\","
subscription_id = ws.subscription_id
print('{}'.format(image.image_location))
print('{}'.format(reg_name))
print('{}'.format(subscription_id))
from azure.mgmt.containerregistry import ContainerRegistryManagementClient
from azure.mgmt import containerregistry
client = ContainerRegistryManagementClient(ws._auth,subscription_id)
result= client.registries.list_credentials(resource_group_name, reg_name, custom_headers=None, raw=False)
username = result.username
password = result.passwords[0].value
# Out:
# amlvdaik10491222845.azurecr.io/sodacans:1
# amlvdaik10491222845
# 75f78a03-482f-4fd8-8c71-5ddc08f92726

# %% [markdown]
# ### Deployment file
# This is the deployment.json file that you will use to deploy your model.  Please see the other sample notebooks on using this file to deploy the new model you created.

# %%
file = open('./deployment-template.json')
contents = file.read()
contents = contents.replace('__MODULE_NAME', module_name)
contents = contents.replace('__REGISTRY_NAME', reg_name)
contents = contents.replace('__REGISTRY_USER_NAME', username)
contents = contents.replace('__REGISTRY_PASSWORD', password)
contents = contents.replace('__REGISTRY_IMAGE_LOCATION', image.image_location)
with open('./deployment.json', 'wt', encoding='utf-8') as output_file:
    output_file.write(contents)

# %%
# Set the deployement 
# !az iot edge set-modules --device-id $iot_device_id --hub-name $iot_hub_name --content deployment.json
