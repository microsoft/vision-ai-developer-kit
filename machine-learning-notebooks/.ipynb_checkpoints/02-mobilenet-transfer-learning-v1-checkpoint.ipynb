# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# # Transfer learning sample (under construction)
# * Create Workspace
# * Register Demo model
# * Build Image
# * Create Hub and Prepare for device and deploy
# * Deploy Model

# %%
# Updates: Connect to existing blob

# %%
# For prod
# !pip install azureml-core
# !pip install azureml-contrib-iot
# !pip install azure-mgmt-containerregistry
# Out:
# Requirement already satisfied: azureml-core in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (1.0.6)
# Requirement already satisfied: azure-storage-nspkg>=3.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (3.1.0)
# Requirement already satisfied: msrest>=0.5.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.6.2)
# Requirement already satisfied: PyJWT in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.7.1)
# Requirement already satisfied: urllib3<1.24,>=1.23 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.23)
# Requirement already satisfied: six>=1.11.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.12.0)
# Requirement already satisfied: azure-mgmt-keyvault>=0.40.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.1.0)
# Requirement already satisfied: requests>=2.19.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.21.0)
# Requirement already satisfied: azure-mgmt-storage>=1.5.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (3.1.1)
# Requirement already satisfied: azure-storage-blob>=1.1.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.4.0)
# Requirement already satisfied: backports.tempfile in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.0)
# Requirement already satisfied: docker in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (3.6.0)
# Requirement already satisfied: azure-cli-core>=2.0.38 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.0.54)
# Requirement already satisfied: azure-common>=1.1.12 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.1.16)
# Requirement already satisfied: jsonpickle in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.0)
# Requirement already satisfied: azure-mgmt-containerregistry>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.6.0)
# Requirement already satisfied: azure-storage-common>=1.1.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (1.4.0)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.4.2)
# Requirement already satisfied: azure-graphrbac>=0.40.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.53.0)
# Requirement already satisfied: azure-cli-profile>=2.0.26 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.1.2)
# Requirement already satisfied: azure-mgmt-authorization>=0.40.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.51.1)
# Requirement already satisfied: pytz in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2018.7)
# Requirement already satisfied: msrestazure>=0.4.33 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.6.0)
# Requirement already satisfied: ruamel.yaml<=0.15.51,>=0.15.35 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.15.51)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.7.5)
# Requirement already satisfied: ndg-httpsclient in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.5.1)
# Requirement already satisfied: SecretStorage<3.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.3.1)
# Requirement already satisfied: azure-mgmt-resource>=1.2.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (2.1.0)
# Requirement already satisfied: pathspec in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.5.9)
# Requirement already satisfied: contextlib2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core) (0.5.5)
# Requirement already satisfied: azure-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-storage-nspkg>=3.0.0->azureml-core) (3.0.2)
# Requirement already satisfied: isodate>=0.6.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.1->azureml-core) (0.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.1->azureml-core) (2018.11.29)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.1->azureml-core) (1.0.0)
# Requirement already satisfied: azure-mgmt-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-mgmt-keyvault>=0.40.0->azureml-core) (3.0.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests>=2.19.1->azureml-core) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests>=2.19.1->azureml-core) (2.8)
# Requirement already satisfied: backports.weakref in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from backports.tempfile->azureml-core) (1.0.post1)
# Requirement already satisfied: docker-pycreds>=0.3.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from docker->azureml-core) (0.4.0)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from docker->azureml-core) (0.54.0)
# Requirement already satisfied: pypiwin32==223; sys_platform == "win32" and python_version >= "3.6" in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from docker->azureml-core) (223)
# Requirement already satisfied: pyyaml~=3.13 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (3.13)
# Requirement already satisfied: adal>=1.2.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (1.2.0)
# Requirement already satisfied: antlr4-python3-runtime; python_version >= "3.0" in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (4.7.2)
# Requirement already satisfied: pip in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (18.1)
# Requirement already satisfied: futures in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (3.1.1)
# Requirement already satisfied: tabulate<=0.8.2,>=0.7.7 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (0.8.2)
# Requirement already satisfied: azure-cli-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (3.0.3)
# Requirement already satisfied: pygments in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (2.3.1)
# Requirement already satisfied: wheel==0.30.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (0.30.0)
# Requirement already satisfied: colorama>=0.3.9 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (0.4.1)
# Requirement already satisfied: argcomplete>=1.8.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (1.9.4)
# Requirement already satisfied: pyopenssl>=17.1.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (18.0.0)
# Requirement already satisfied: azure-cli-telemetry in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (1.0.0)
# Requirement already satisfied: paramiko>=2.0.8 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (2.4.2)
# Requirement already satisfied: humanfriendly>=4.7 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (4.17)
# Requirement already satisfied: knack==0.5.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (0.5.1)
# Requirement already satisfied: jmespath in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core) (0.9.3)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core) (0.24.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core) (1.11.5)
# Requirement already satisfied: azure-cli-command-modules-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-profile>=2.0.26->azureml-core) (2.0.2)
# Requirement already satisfied: pyasn1>=0.1.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from ndg-httpsclient->azureml-core) (0.4.5)
# Requirement already satisfied: oauthlib>=0.6.2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core) (2.1.0)
# Requirement already satisfied: pywin32>=223 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from pypiwin32==223; sys_platform == "win32" and python_version >= "3.6"->docker->azureml-core) (224)
# Requirement already satisfied: portalocker==1.2.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-telemetry->azure-cli-core>=2.0.38->azureml-core) (1.2.1)
# Requirement already satisfied: applicationinsights>=0.11.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-telemetry->azure-cli-core>=2.0.38->azureml-core) (0.11.7)
# Requirement already satisfied: pynacl>=1.0.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core) (1.3.0)
# Requirement already satisfied: bcrypt>=3.1.3 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core) (3.1.5)
# Requirement already satisfied: pyreadline; sys_platform == "win32" in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from humanfriendly>=4.7->azure-cli-core>=2.0.38->azureml-core) (2.1)
# Requirement already satisfied: pycparser in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cffi!=1.11.3,>=1.7->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core) (2.19)
# Requirement already satisfied: azureml-contrib-iot in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (1.0.6)
# Requirement already satisfied: azureml-core==1.0.6.* in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-contrib-iot) (1.0.6)
# Requirement already satisfied: contextlib2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.5.5)
# Requirement already satisfied: azure-mgmt-resource>=1.2.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.1.0)
# Requirement already satisfied: ndg-httpsclient in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.5.1)
# Requirement already satisfied: six>=1.11.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.7.5)
# Requirement already satisfied: docker in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (3.6.0)
# Requirement already satisfied: pathspec in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.5.9)
# Requirement already satisfied: azure-storage-nspkg>=3.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (3.1.0)
# Requirement already satisfied: ruamel.yaml<=0.15.51,>=0.15.35 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.15.51)
# Requirement already satisfied: azure-cli-profile>=2.0.26 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.1.2)
# Requirement already satisfied: azure-graphrbac>=0.40.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.53.0)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.4.2)
# Requirement already satisfied: azure-mgmt-keyvault>=0.40.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.1.0)
# Requirement already satisfied: azure-common>=1.1.12 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.1.16)
# Requirement already satisfied: requests>=2.19.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.21.0)
# Requirement already satisfied: azure-mgmt-storage>=1.5.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (3.1.1)
# Requirement already satisfied: azure-storage-common>=1.1.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.4.0)
# Requirement already satisfied: msrestazure>=0.4.33 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.6.0)
# Requirement already satisfied: PyJWT in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.7.1)
# Requirement already satisfied: azure-cli-core>=2.0.38 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.0.54)
# Requirement already satisfied: SecretStorage<3.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.3.1)
# Requirement already satisfied: urllib3<1.24,>=1.23 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.23)
# Requirement already satisfied: azure-storage-blob>=1.1.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.4.0)
# Requirement already satisfied: jsonpickle in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.0)
# Requirement already satisfied: azure-mgmt-authorization>=0.40.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.51.1)
# Requirement already satisfied: backports.tempfile in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (1.0)
# Requirement already satisfied: msrest>=0.5.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (0.6.2)
# Requirement already satisfied: azure-mgmt-containerregistry>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2.6.0)
# Requirement already satisfied: pytz in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azureml-core==1.0.6.*->azureml-contrib-iot) (2018.7)
# Requirement already satisfied: pyasn1>=0.1.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from ndg-httpsclient->azureml-core==1.0.6.*->azureml-contrib-iot) (0.4.5)
# Requirement already satisfied: PyOpenSSL in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from ndg-httpsclient->azureml-core==1.0.6.*->azureml-contrib-iot) (18.0.0)
# Requirement already satisfied: pypiwin32==223; sys_platform == "win32" and python_version >= "3.6" in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from docker->azureml-core==1.0.6.*->azureml-contrib-iot) (223)
# Requirement already satisfied: docker-pycreds>=0.3.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from docker->azureml-core==1.0.6.*->azureml-contrib-iot) (0.4.0)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from docker->azureml-core==1.0.6.*->azureml-contrib-iot) (0.54.0)
# Requirement already satisfied: azure-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-storage-nspkg>=3.0.0->azureml-core==1.0.6.*->azureml-contrib-iot) (3.0.2)
# Requirement already satisfied: azure-cli-command-modules-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-profile>=2.0.26->azureml-core==1.0.6.*->azureml-contrib-iot) (2.0.2)
# Requirement already satisfied: idna>=2.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.6.*->azureml-contrib-iot) (2.8)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.6.*->azureml-contrib-iot) (0.24.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.6.*->azureml-contrib-iot) (1.11.5)
# Requirement already satisfied: azure-mgmt-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-mgmt-keyvault>=0.40.0->azureml-core==1.0.6.*->azureml-contrib-iot) (3.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests>=2.19.1->azureml-core==1.0.6.*->azureml-contrib-iot) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests>=2.19.1->azureml-core==1.0.6.*->azureml-contrib-iot) (3.0.4)
# Requirement already satisfied: adal<2.0.0,>=0.6.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrestazure>=0.4.33->azureml-core==1.0.6.*->azureml-contrib-iot) (1.2.0)
# Requirement already satisfied: pip in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (18.1)
# Requirement already satisfied: azure-cli-telemetry in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (1.0.0)
# Requirement already satisfied: colorama>=0.3.9 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (0.4.1)
# Requirement already satisfied: pyyaml~=3.13 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (3.13)
# Requirement already satisfied: humanfriendly>=4.7 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (4.17)
# Requirement already satisfied: knack==0.5.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (0.5.1)
# Requirement already satisfied: azure-cli-nspkg>=2.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (3.0.3)
# Requirement already satisfied: paramiko>=2.0.8 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (2.4.2)
# Requirement already satisfied: futures in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (3.1.1)
# Requirement already satisfied: antlr4-python3-runtime; python_version >= "3.0" in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (4.7.2)
# Requirement already satisfied: pygments in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (2.3.1)
# Requirement already satisfied: jmespath in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (0.9.3)
# Requirement already satisfied: argcomplete>=1.8.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (1.9.4)
# Requirement already satisfied: tabulate<=0.8.2,>=0.7.7 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (0.8.2)
# Requirement already satisfied: wheel==0.30.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (0.30.0)
# Requirement already satisfied: backports.weakref in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from backports.tempfile->azureml-core==1.0.6.*->azureml-contrib-iot) (1.0.post1)
# Requirement already satisfied: isodate>=0.6.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.1->azureml-core==1.0.6.*->azureml-contrib-iot) (0.6.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.1->azureml-core==1.0.6.*->azureml-contrib-iot) (1.0.0)
# Requirement already satisfied: pywin32>=223 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from pypiwin32==223; sys_platform == "win32" and python_version >= "3.6"->docker->azureml-core==1.0.6.*->azureml-contrib-iot) (224)
# Requirement already satisfied: pycparser in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cffi!=1.11.3,>=1.7->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.6.*->azureml-contrib-iot) (2.19)
# Requirement already satisfied: portalocker==1.2.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-telemetry->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (1.2.1)
# Requirement already satisfied: applicationinsights>=0.11.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-cli-telemetry->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (0.11.7)
# Requirement already satisfied: pyreadline; sys_platform == "win32" in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from humanfriendly>=4.7->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (2.1)
# Requirement already satisfied: bcrypt>=3.1.3 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (3.1.5)
# Requirement already satisfied: pynacl>=1.0.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==1.0.6.*->azureml-contrib-iot) (1.3.0)
# Requirement already satisfied: oauthlib>=0.6.2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core==1.0.6.*->azureml-contrib-iot) (2.1.0)
# Requirement already satisfied: azure-mgmt-containerregistry in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (2.6.0)
# Requirement already satisfied: msrest>=0.5.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-mgmt-containerregistry) (0.6.2)
# Requirement already satisfied: msrestazure<2.0.0,>=0.4.32 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-mgmt-containerregistry) (0.6.0)
# Requirement already satisfied: azure-common~=1.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from azure-mgmt-containerregistry) (1.1.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.0->azure-mgmt-containerregistry) (2018.11.29)
# Requirement already satisfied: isodate>=0.6.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.0->azure-mgmt-containerregistry) (0.6.0)
# Requirement already satisfied: requests~=2.16 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.0->azure-mgmt-containerregistry) (2.21.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrest>=0.5.0->azure-mgmt-containerregistry) (1.0.0)
# Requirement already satisfied: adal<2.0.0,>=0.6.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (1.2.0)
# Requirement already satisfied: six in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from isodate>=0.6.0->msrest>=0.5.0->azure-mgmt-containerregistry) (1.12.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-mgmt-containerregistry) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-mgmt-containerregistry) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-mgmt-containerregistry) (1.23)
# Requirement already satisfied: oauthlib>=0.6.2 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-mgmt-containerregistry) (2.1.0)
# Requirement already satisfied: cryptography>=1.1.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.1.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (2.7.5)
# Requirement already satisfied: PyJWT>=1.0.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (1.7.1)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (0.24.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (1.11.5)
# Requirement already satisfied: pycparser in c:\programdata\miniconda3\envs\vdaik1\lib\site-packages (from cffi!=1.11.3,>=1.7->cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-containerregistry) (2.19)

# %%
import os
print(os.__file__)
# Out:
# C:\ProgramData\Miniconda3\envs\vdaik1\lib\os.py

# %%
# Check core SDK version number
import azureml.core as azcore

print("SDK version:", azcore.VERSION)
# Out:
# SDK version: 1.0.6

# %% [markdown]
# ### Create a Workspace
# #### Change this cell from markdown to code and run this if you need to create a workspace
# #### Update the values for your workspace below
# ws=Workspace.create(subscription_id="replace-with-subscription-id",
#                 resource_group="your-resource-group",
#                 name="your-workspace-name",
#                 location="eastus2")
#
# ws.write_config()

# %%
#Initialize Workspace 
from azureml.core import Workspace

ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# Found the config file in: c:\Users\tedway\git\vdaik\aml_config\config.json
# aml-vdaik-1
# tedway-vienna1-rg
# eastus2
# 75f78a03-482f-4fd8-8c71-5ddc08f92726

# %% [markdown]
# ### Create Experiment
# Experiment is a logical container in an Azure ML Workspace. It hosts run records which can include run metrics and output artifacts from your experiments.

# %%
experiment_name = 'soda_cans'

from azureml.core import Experiment
exp = Experiment(workspace = ws, name = experiment_name)

# %% [markdown]
# ## Get data
# ### Option 1: Upload data files into datastore
# Every workspace comes with a default datastore (and you can register more) which is backed by the Azure blob storage account associated with the workspace. We can use it to transfer data from local to the cloud, and access it from the compute target.

# %%
# get the default datastore
ds = ws.get_default_datastore()
print(ds.name, ds.datastore_type, ds.account_name, ds.container_name)
# Out:
# workspaceblobstore AzureBlob amlvdaik14969151586 azureml-blobstore-1721629c-c5b4-4182-940b-a0cdff79ba52

# %%
data_path = experiment_name + '_training_data'
ds.upload(src_dir='data/soda_cans', target_path=data_path, overwrite=True)
# Out:
# Uploading data/soda_cans\coke\IMG_20181207_154649.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154652.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154654.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154656.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154659.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154671.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154672.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154673.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154701.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154704.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154706.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154708.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154710.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154712.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154714.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154724.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154726.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154732.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154735.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154737.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154739.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154741.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154743.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154746.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154748.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154750.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154752.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154756.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154758.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154800.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154802.jpg
# Uploading data/soda_cans\coke\IMG_20181207_154804.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154649.jpg, 1 files out of an estimated total of 133
# Uploading data/soda_cans\coke\IMG_20181207_154805.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154672.jpg, 2 files out of an estimated total of 133
# Uploading data/soda_cans\coke\IMG_20181207_154806.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154704.jpg, 3 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154919.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154714.jpg, 4 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154922.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154737.jpg, 5 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154925.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154701.jpg, 6 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154656.jpg, 7 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154927.jpg
# Uploading data/soda_cans\duck\IMG_20181207_154929.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154800.jpg, 8 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154931.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154671.jpg, 9 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154659.jpg, 10 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154933.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154673.jpg, 11 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154936.jpg
# Uploading data/soda_cans\duck\IMG_20181207_154938.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154706.jpg, 12 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154940.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154708.jpg, 13 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154945.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154756.jpg, 14 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154654.jpg, 15 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_154947.jpg
# Uploading data/soda_cans\duck\IMG_20181207_154949.jpg
# Uploaded data/soda_cans\coke\IMG_20181207_154652.jpg, 16 files out of an estimated total of 133
# Uploading data/soda_cans\duck\IMG_20181207_
files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154341.jpg
# Uploading data/soda_cans\pepsi\IMG_20181207_154391.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154349.jpg, 85 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154392.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154377.jpg, 86 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154393.jpg
# Uploaded data/soda_cans\pepsi\IMG_20181207_154330.jpg, 87 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154539.jpg
# Uploaded data/soda_cans\pepsi\IMG_20181207_154327.jpg, 88 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154542.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154992.jpg, 89 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154545.jpg
# Uploaded data/soda_cans\pepsi\IMG_20181207_154324.jpg, 90 files out of an estimated total of 133
# Uploaded data/soda_cans\ice\IMG_20181207_154833.jpg, 91 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154546.jpg
# Uploading data/soda_cans\pepsi\IMG_20181207_154551.jpg
# Uploaded data/soda_cans\pepsi\IMG_20181207_154335.jpg, 92 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154552.jpg
# Uploaded data/soda_cans\pepsi\IMG_20181207_154337.jpg, 93 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154338.jpg, 94 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154553.jpg
# Uploading data/soda_cans\pepsi\IMG_20181207_154555.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154527.jpg, 95 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154556.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154378.jpg, 96 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154812.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154408.jpg, 97 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154814.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154837.jpg, 98 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154815.jpg
# Uploaded data/soda_cans\pepsi\IMG_20181207_154545.jpg, 99 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154817.jpg
# Uploaded data/soda_cans\duck\IMG_20181207_154993.jpg, 100 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154818.jpg
# Uploaded data/soda_cans\pepsi\IMG_20181207_154552.jpg, 101 files out of an estimated total of 133
# Uploading data/soda_cans\pepsi\IMG_20181207_154820.jpg
# Uploaded data/soda_cans\ice\IMG_20181207_154392.jpg, 102 files out of an estimated total of 133
# Uploaded data/soda_cans\ice\IMG_20181207_154376.jpg, 103 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154551.jpg, 104 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154555.jpg, 105 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154553.jpg, 106 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154331.jpg, 107 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154539.jpg, 108 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154307.jpg, 109 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154817.jpg, 110 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154546.jpg, 111 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154748.jpg, 112 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154391.jpg, 113 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154392.jpg, 114 files out of an estimated total of 133
# Uploaded data/soda_cans\ice\IMG_20181207_154401.jpg, 115 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154393.jpg, 116 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154820.jpg, 117 files out of an estimated total of 133
# Uploaded data/soda_cans\ice\IMG_20181207_154418.jpg, 118 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154814.jpg, 119 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154340.jpg, 120 files out of an estimated total of 133
# Uploaded data/soda_cans\ice\IMG_20181207_154393.jpg, 121 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154341.jpg, 122 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154321.jpg, 123 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154334.jpg, 124 files out of an estimated total of 133
# Uploaded data/soda_cans\ice\IMG_20181207_154830.jpg, 125 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154556.jpg, 126 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154818.jpg, 127 files out of an estimated total of 133
# Uploaded data/soda_cans\ice\IMG_20181207_154832.jpg, 128 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154339.jpg, 129 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154815.jpg, 130 files out of an estimated total of 133
# Uploaded data/soda_cans\coke\IMG_20181207_154726.jpg, 131 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154542.jpg, 132 files out of an estimated total of 133
# Uploaded data/soda_cans\pepsi\IMG_20181207_154812.jpg, 133 files out of an estimated total of 133
# $AZUREML_DATAREFERENCE_27a8b49468f84ed394a0104325b63b55

# %% [markdown]
# ### Option 2: Use existing datastore in Azure blob storage

# %%
from azureml.core.datastore import Datastore
ds = Datastore.register_azure_blob_container(workspace=ws, 
                                         datastore_name='amlvdaik14969151586', 
                                         container_name='azureml-blobstore-1721629c-c5b4-4182-940b-a0cdff79ba52',
                                         account_name='amlvdaik14969151586', 
                                         account_key='h3nlK9lc3OGFzCxWx8gs2Anxpsx5WoBfqV25hRtKHtTyivXkGJZ9/jNjmUcTeN6WPAeXYZlA1me/NhOeLXyCAg==',
                                         create_if_not_exists=False)
data_path = "soda_cans_training_data" # This is the path to the folder in the blob container. Set this to None to get all the contents.
print(ds.name, ds.datastore_type, ds.account_name, ds.container_name)
# Out:
# amlvdaik14969151586 AzureBlob amlvdaik14969151586 azureml-blobstore-1721629c-c5b4-4182-940b-a0cdff79ba52

# %% [markdown]
# ### Configure for using ACI
# Linux-based ACI is available in West US, East US, West Europe, North Europe, West US 2, Southeast Asia, Australia East, East US 2, and Central US regions.  See details [here](https://docs.microsoft.com/en-us/azure/container-instances/container-instances-quotas#region-availability)

# %%
from azureml.core.runconfig import DataReferenceConfiguration
dr = DataReferenceConfiguration(datastore_name=ds.name, 
                   path_on_datastore=data_path, 
                   mode='download', # download files from datastore to compute target
                   overwrite=True)

# %% [markdown]
# Set the system to build a conda environment based on the run configuration. Once the environment is built, and if you don't change your dependencies, it will be reused in subsequent runs.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# choose a name for your cluster
cluster_name = "cpucluster1"

try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing compute target.')
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_D3', max_nodes=2)

    # create the cluster
    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

    compute_target.wait_for_completion(show_output=True)

# Use the 'status' property to get a detailed status for the current AmlCompute. 
print(compute_target.status.serialize())
# Out:
# Found existing compute target.
# {'allocationState': 'Steady', 'allocationStateTransitionTime': '2019-01-15T03:08:10.784000+00:00', 'creationTime': '2019-01-09T23:59:06.540668+00:00', 'currentNodeCount': 0, 'errors': None, 'modifiedTime': '2019-01-09T23:59:44.897457+00:00', 'nodeStateCounts': {'idleNodeCount': 0, 'leavingNodeCount': 0, 'preemptedNodeCount': 0, 'preparingNodeCount': 0, 'runningNodeCount': 0, 'unusableNodeCount': 0}, 'provisioningState': 'Succeeded', 'provisioningStateTransitionTime': None, 'scaleSettings': {'minNodeCount': 0, 'maxNodeCount': 2, 'nodeIdleTimeBeforeScaleDown': 'PT120S'}, 'targetNodeCount': 0, 'vmPriority': 'Dedicated', 'vmSize': 'STANDARD_D3'}

# %%
from azureml.core.runconfig import RunConfiguration, DEFAULT_CPU_IMAGE
from azureml.core.conda_dependencies import CondaDependencies

# create a new runconfig object
run_config = RunConfiguration(framework = "python")

# Set compute target
run_config.target = compute_target.name

# set the data reference of the run configuration
run_config.data_references = {ds.name: dr}

# enable Docker 
run_config.environment.docker.enabled = True

# set Docker base image to the default CPU-based image
run_config.environment.docker.base_image = DEFAULT_CPU_IMAGE

# use conda_dependencies.yml to create a conda environment in the Docker image for execution
run_config.environment.python.user_managed_dependencies = False

# auto-prepare the Docker image when used for execution (if it is not already prepared)
run_config.auto_prepare_environment = True

# specify CondaDependencies obj
run_config.environment.python.conda_dependencies = CondaDependencies.create(conda_packages=['tensorflow==1.8.0'])

# %% [markdown]
# from azureml.core.runconfig import RunConfiguration
#
# # create a new runconfig object
# run_config = RunConfiguration.load('.', 'aci')
# run_config.target = compute_target.name
#
# # set the data reference of the run configuration
# run_config.data_references = {ds.name: dr}

# %% [markdown]
# ### Submit the Experiment
# Submit script to run in the Docker image in the remote VM. If you run this for the first time, the system will download the base image, layer in packages specified in the conda_dependencies.yml file on top of the base image, create a container and then execute the script in the container.

# %%
from azureml.core import Run
from azureml.core import ScriptRunConfig

src = ScriptRunConfig(source_directory = './02-mobilenet-transfer-learning-scripts', script = 'retrain.py', run_config = run_config, 
                      # pass the datastore reference as a parameter to the training script
                      arguments=['--image_dir', str(ds.as_download()),
                                 '--architecture', 'mobilenet_1.0_224',
                                 '--output_graph', 'outputs/retrained_graph.pb',
                                 '--output_labels', 'outputs/output_labels.txt',
                                 '--model_download_url', 'https://raw.githubusercontent.com/rakelkar/models/master/model_output/',
                                 '--model_file_name', 'imagenet_2_frozen.pb'
                                ])
run = exp.submit(config=src)

# %%
run
# Out:
# Run(Experiment: soda_cans,
# Id: soda_cans_1547579216299,
# Type: azureml.scriptrun,
# Status: Queued)

# %%
run.wait_for_completion(show_output=True)
# Out:
# RunId: soda_cans_1547579216299
#
# Streaming azureml-logs/60_control_log.txt
# =========================================
#
# Streaming log file azureml-logs/60_control_log.txt
# Streaming log file azureml-logs/80_driver_log.txt
#
# Streaming azureml-logs/80_driver_log.txt
# ========================================
#
# Downloading soda_cans_training_data/coke/IMG_20181207_154649.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154652.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154654.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154656.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154659.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154671.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154672.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154673.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154701.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154704.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154706.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154708.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154710.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154712.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154714.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154724.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154726.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154732.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154735.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154737.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154739.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154741.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154743.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154746.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154748.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154750.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154752.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154756.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154758.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154800.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154802.jpg
# Downloading soda_cans_training_data/coke/IMG_20181207_154804.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154654.jpg, 1 files out of an estimated total of 133
# Downloading soda_cans_training_data/coke/IMG_20181207_154805.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154671.jpg, 2 files out of an estimated total of 133
# Downloading soda_cans_training_data/coke/IMG_20181207_154806.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154701.jpg, 3 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154919.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154672.jpg, 4 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154922.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154659.jpg, 5 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154925.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154706.jpg, 6 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154927.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154652.jpg, 7 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154929.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154656.jpg, 8 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154931.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154735.jpg, 9 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154933.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154710.jpg, 10 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154936.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154737.jpg, 11 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154938.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154673.jpg, 12 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154940.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154732.jpg, 13 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154945.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154739.jpg, 14 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154947.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154726.jpg, 15 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154949.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154649.jpg, 16 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154951.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154708.jpg, 17 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154953.jpg
# Downloaded soda_cans_training_data/duck/IMG_20181207_154922.jpg, 18 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154955.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154712.jpg, 19 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154958.jpg
# Downloaded soda_cans_training_data/duck/IMG_20181207_154919.jpg, 20 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154961.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154758.jpg, 21 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154962.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154714.jpg, 22 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154963.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154743.jpg, 23 files out of an estimated total of 133
# Downloaded soda_cans_training_data/coke/IMG_20181207_154724.jpg, 24 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154964.jpg
# Downloading soda_cans_training_data/duck/IMG_20181207_154965.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154750.jpg, 25 files out of an estimated total of 133
# Downloaded soda_cans_training_data/coke/IMG_20181207_154806.jpg, 26 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154966.jpg
# Downloading soda_cans_training_data/duck/IMG_20181207_154967.jpg
# Downloaded soda_cans_training_data/duck/IMG_20181207_154945.jpg, 27 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154968.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154704.jpg, 28 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154969.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154746.jpg, 29 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154970.jpg
# Downloaded soda_cans_training_data/duck/IMG_20181207_154961.jpg, 30 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154971.jpg
# Downloaded soda_cans_training_data/duck/IMG_20181207_154938.jpg, 31 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154991.jpg
# Downloaded soda_cans_training_data/duck/IMG_20181207_154927.jpg, 32 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154992.jpg
# Downloaded soda_cans_training_data/coke/IMG_20181207_154804.jpg, 33 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_154993.jpg
# Downloaded soda_cans_training_data/duck/IMG_20181207_154947.jpg, 34 files out of an estimated total of 133
# Downloaded soda_cans_training_data/duck/IMG_20181207_154951.jpg, 35 files out of an estimated total of 133
# Downloading soda_cans_training_data/duck/IMG_20181207_155000.jpg
# Downloaded soda_cans_training_data/duck/IMG_20181207_
Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:41.222328: Step 3850: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:41.222557: Step 3850: Cross entropy = 0.000298
# INFO:tensorflow:2019-01-15 19:20:41.288045: Step 3850: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:41.941596: Step 3860: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:41.941836: Step 3860: Cross entropy = 0.000186
# INFO:tensorflow:2019-01-15 19:20:42.007069: Step 3860: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:42.663236: Step 3870: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:42.663461: Step 3870: Cross entropy = 0.000175
# INFO:tensorflow:2019-01-15 19:20:42.727151: Step 3870: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:43.392440: Step 3880: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:43.392673: Step 3880: Cross entropy = 0.000190
# INFO:tensorflow:2019-01-15 19:20:43.462061: Step 3880: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:44.192187: Step 3890: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:44.192419: Step 3890: Cross entropy = 0.000210
# INFO:tensorflow:2019-01-15 19:20:44.271540: Step 3890: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:44.943861: Step 3900: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:44.944082: Step 3900: Cross entropy = 0.000243
# INFO:tensorflow:2019-01-15 19:20:45.026889: Step 3900: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:45.728029: Step 3910: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:45.728285: Step 3910: Cross entropy = 0.000280
# INFO:tensorflow:2019-01-15 19:20:45.808513: Step 3910: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:46.482771: Step 3920: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:46.482995: Step 3920: Cross entropy = 0.000163
# INFO:tensorflow:2019-01-15 19:20:46.546574: Step 3920: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:47.262068: Step 3930: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:47.262324: Step 3930: Cross entropy = 0.000343
# INFO:tensorflow:2019-01-15 19:20:47.336281: Step 3930: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:47.988676: Step 3940: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:47.988904: Step 3940: Cross entropy = 0.000252
# INFO:tensorflow:2019-01-15 19:20:48.054155: Step 3940: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:48.730470: Step 3950: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:48.730706: Step 3950: Cross entropy = 0.000278
# INFO:tensorflow:2019-01-15 19:20:48.804401: Step 3950: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:49.478703: Step 3960: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:49.478967: Step 3960: Cross entropy = 0.000394
# INFO:tensorflow:2019-01-15 19:20:49.544149: Step 3960: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:50.203056: Step 3970: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:50.203324: Step 3970: Cross entropy = 0.000316
# INFO:tensorflow:2019-01-15 19:20:50.271292: Step 3970: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:50.926315: Step 3980: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:50.926537: Step 3980: Cross entropy = 0.000268
# INFO:tensorflow:2019-01-15 19:20:50.991082: Step 3980: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:51.720940: Step 3990: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:51.721161: Step 3990: Cross entropy = 0.000228
# INFO:tensorflow:2019-01-15 19:20:51.789189: Step 3990: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2019-01-15 19:20:52.385753: Step 3999: Train accuracy = 100.0%
# INFO:tensorflow:2019-01-15 19:20:52.385985: Step 3999: Cross entropy = 0.000185
# INFO:tensorflow:2019-01-15 19:20:52.450072: Step 3999: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:Final test accuracy = 100.0% (N=10)
# INFO:tensorflow:Froze 2 variables.
# Converted 2 variables to const ops.
#
#
# The experiment completed successfully. Finalizing run...
# Logging experiment finalizing status in history service
#
# Execution Summary
# =================
# RunId: soda_cans_1547579216299
# {'runId': 'soda_cans_1547579216299',
#  'target': 'cpucluster1',
#  'status': 'Finalizing',
#  'startTimeUtc': '2019-01-15T19:12:15.426149Z',
#  'properties': {'azureml.runsource': 'experiment',
#   'ContentSnapshotId': '2b36cb85-e6d7-4262-a61e-956c2c2cb75d'},
#  'runDefinition': {'Script': 'retrain.py',
#   'Arguments': ['--image_dir',
#    '$AZUREML_DATAREFERENCE_workspaceblobstore',
#    '--architecture',
#    'mobilenet_1.0_224',
#    '--output_graph',
#    'outputs/retrained_graph.pb',
#    '--output_labels',
#    'outputs/output_labels.txt',
#    '--model_download_url',
#    'https://raw.githubusercontent.com/rakelkar/models/master/model_output/',
#    '--model_file_name',
#    'imagenet_2_frozen.pb'],
#   'SourceDirectoryDataStore': None,
#   'Framework': 0,
#   'Communicator': 0,
#   'Target': 'cpucluster1',
#   'DataReferences': {'workspaceblobstore': {'DataStoreName': 'workspaceblobstore',
#     'Mode': 'Download',
#     'PathOnDataStore': 'soda_cans_training_data',
#     'PathOnCompute': None,
#     'Overwrite': True}},
#   'JobName': None,
#   'AutoPrepareEnvironment': True,
#   'MaxRunDurationSeconds': None,
#   'NodeCount': 1,
#   'Environment': {'Python': {'InterpreterPath': 'python',
#     'UserManagedDependencies': False,
#     'CondaDependencies': {'name': 'project_environment',
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-defaults==1.0.6']},
#       'tensorflow==1.8.0']}},
#    'EnvironmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'Docker': {'BaseImage': 'mcr.microsoft.com/azureml/base:0.2.0',
#     'Enabled': True,
#     'SharedVolumes': True,
#     'Preparation': None,
#     'GpuSupport': False,
#     'ShmSize': '1g',
#     'Arguments': [],
#     'BaseImageRegistry': {'Address': None,
#      'Username': None,
#      'Password': None}},
#    'Spark': {'Repositories': ['https://mmlspark.azureedge.net/maven'],
#     'Packages': [{'Group': 'com.microsoft.ml.spark',
#       'Artifact': 'mmlspark_2.11',
#       'Version': '0.12'}],
#     'PrecachePackages': True}},
#   'History': {'OutputCollection': True},
#   'Spark': {'Configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'BatchAi': {'NodeCount': 0},
#   'AmlCompute': {'Name': None,
#    'VmSize': None,
#    'VmPriority': None,
#    'RetainCluster': False,
#    'ClusterMaxNodeCount': 1},
#   'Tensorflow': {'WorkerCount': 1, 'ParameterServerCount': 1},
#   'Mpi': {'ProcessCountPerNode': 1},
#   'Hdi': {'YarnDeployMode': 2},
#   'ContainerInstance': {'Region': None, 'CpuCores': 0, 'MemoryGb': 0},
#   'ExposedPorts': None,
#   'PrepareEnvironment': None},
#  'logFiles': {'azureml-logs/60_control_log.txt': 'https://amlvdaik14969151586.blob.core.windows.net/azureml/ExperimentRun/dcid.soda_cans_1547579216299/azureml-logs/60_control_log.txt?sv=2018-03-28&sr=b&sig=88%2FMQ%2BCf%2FMTC8rn4YfhJo%2BPD%2BpfWCerq%2FnhP1c9f6tQ%3D&st=2019-01-15T19%3A10%3A57Z&se=2019-01-16T03%3A20%3A57Z&sp=r',
#   'azureml-logs/80_driver_log.txt': 'https://amlvdaik14969151586.blob.core.windows.net/azureml/ExperimentRun/dcid.soda_cans_1547579216299/azureml-logs/80_driver_log.txt?sv=2018-03-28&sr=b&sig=2JXi%2Bgk1rpLQmzGtVopdUonl1QdVD2TNc9ukkwp0g0k%3D&st=2019-01-15T19%3A10%3A57Z&se=2019-01-16T03%3A20%3A57Z&sp=r',
#   'azureml-logs/azureml.log': 'https://amlvdaik14969151586.blob.core.windows.net/azureml/ExperimentRun/dcid.soda_cans_1547579216299/azureml-logs/azureml.log?sv=2018-03-28&sr=b&sig=4QmA8FuGFwpLV2bOuYSvi5CT4TqR3JPgBh%2FZkJWGELY%3D&st=2019-01-15T19%3A10%3A57Z&se=2019-01-16T03%3A20%3A57Z&sp=r'}}

# %%
# Upload the VAM config file to the outputs folder
run.upload_file(name = 'outputs/va-snpe-engine-library_config.json', path_or_stream = './02-mobilenet-transfer-learning-scripts/va-snpe-engine-library_config.json')

# %%
from azureml.core.model import Model

# This is registering the model from the run object.  It's different than the other sample notebook that uses the local
# file from the Model objec.
model = run.register_model(model_name = experiment_name,
                           model_path = 'outputs/')

print(model.name, model.url, model.version, model.id, model.created_time)
# Out:
# soda_cans aml://asset/076cf8c08e0d47e08a0d3644a768f2a6 12 soda_cans:12 2019-01-15 07:11:17.422011+00:00

# %%
### If you want to upload the model, convert this cell to code

from azureml.core.model import Model

model = Model.register(model_path = "models/mobilenet-soda-cans/orig/",
                      model_name = "soda_cans",
                      tags = {"data": "Imagenet", "model": "object_detection", "type": "imagenet"},
                      description = "Retrained soda cans based on MobileNet",
                      workspace = ws)
# Out:
# Registering model soda_cans

# %%
from azureml.contrib.iot.model_converters import SnpeConverter

# submit a compile request
compile_request = SnpeConverter.convert_tf_model(
    ws,
    source_model=model,
    input_node="input",
    input_dims="1,224,224,3",
    outputs_nodes = ["final_result"],
    allow_unconsumed_nodes = True)
print(compile_request._operation_id)
# Out:
# 3d94101b-7286-4e3f-984f-ceec05862060

# %%
# wait for the request to complete
compile_request.wait_for_completion(show_output=True)
# Out:
# NotStarted..
# Succeeded
# Operation 3d94101b-7286-4e3f-984f-ceec05862060 completed, operation state "Succeeded"
# sas url to download model conversion logs https://amlvdaik14969151586.blob.core.windows.net/azureml/LocalUpload/a156ceef6b3647a4a8981f8c80748acd/soda_cans.14.dlc.tar.gz-userlog?sv=2018-03-28&sr=b&sig=VSbPUtmOsdATZ99kB08J%2BQUfxAdqrRbGDVHJkTZcRVU%3D&st=2019-01-15T19%3A15%3A51Z&se=2019-01-16T03%3A25%3A51Z&sp=r
# [2019-01-15 19:25:38Z]: Starting model conversion process
# [2019-01-15 19:25:38Z]: Downloading model for conversion
# [2019-01-15 19:25:39Z]: Converting model
# [2019-01-15 19:25:41Z]: converter std: Executing python /snpe-1.19.2/bin/x86_64-linux-clang/snpe-tensorflow-to-dlc --graph /tmp/yw1hjl4u.bpw/input/retrained_graph.pb -i input 1,224,224,3 --dlc /tmp/yw1hjl4u.bpw/output/model.dlc --out_node final_result --allow_unconsumed_nodes in /app
# [2019-01-15 19:25:41Z]: converter std: Stream stdout is True
# [2019-01-15 19:25:41Z]: converter std: 2019-01-15 19:25:40.371907: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# [2019-01-15 19:25:41Z]: converter std: Execution took 0.001202s for ['python', '/snpe-1.19.2/bin/x86_64-linux-clang/snpe-tensorflow-to-dlc', '--graph', '/tmp/yw1hjl4u.bpw/input/retrained_graph.pb', '-i', u'input', u'1,224,224,3', '--dlc', '/tmp/yw1hjl4u.bpw/output/model.dlc', '--out_node', u'final_result', '--allow_unconsumed_nodes'] in /app
# [2019-01-15 19:25:41Z]: Uploading conversion results
# [2019-01-15 19:25:43Z]: Conversion completed with result Success
# True

# %%
# Get converted model
converted_model = compile_request.result
print(converted_model.name, converted_model.url, converted_model.version, converted_model.id, converted_model.created_time)
# Out:
# soda_cans.14.dlc aml://asset/25f5c59cc3054337b433f33ba0dfb62e 1 soda_cans.14.dlc:1 2019-01-15 19:25:48.344727+00:00

# %%
from azureml.core.image import Image
from azureml.contrib.iot import IotContainerImage
print ('We will create an image for you now ...')
image_config = IotContainerImage.image_configuration(
                                 architecture="arm32v7",
                                 execution_script="main.py", 
                                 dependencies=["camera.py","iot.py","ipcprovider.py","utility.py", "frame_iterators.py"],
                                 docker_file="Dockerfile", 
                                 tags = ["mobilenet"],
                                 description = "MobileNet model retrained soda cans")
image = Image.create(name = "mobilenetsoda",
                     # this is the model object 
                     models = [converted_model],
                     image_config = image_config, 
                     workspace = ws)
image.wait_for_creation(show_output = True)
# Out:
# We will create an image for you now ...
# Creating image
# Running...........................................................................................................................................
# SucceededImage creation operation finished for image mobilenetsoda:6, operation "Succeeded"

# %%
# Parameter list

# Pick a name for what you want to call the module you deploy to the camera
module_name = "visionsample"

# Resource group in Azure 
resource_group_name= ws.resource_group
iot_rg="vaidk_"+resource_group_name

# Azure region where your services will be provisioned
iot_location="eastus2"

# Azure IoT Hub name
iot_hub_name="iothub-"+ ws.get_details()["name"]

# Pick a name for your camera
iot_device_id="vadik_"+ ws.get_details()["name"]

# Pick a name for the deployment configuration
iot_deployment_id="demovaidk"

# %%
# Getting your container details
container_reg = ws.get_details()["containerRegistry"]
reg_name=container_reg.split("/")[-1]
container_url = "\"" + image.image_location + "\","
subscription_id = ws.subscription_id
print('{}'.format(image.image_location))
print('{}'.format(reg_name))
print('{}'.format(subscription_id))
from azure.mgmt.containerregistry import ContainerRegistryManagementClient
from azure.mgmt import containerregistry
client = ContainerRegistryManagementClient(ws._auth,subscription_id)
result= client.registries.list_credentials(resource_group_name, reg_name, custom_headers=None, raw=False)
username = result.username
password = result.passwords[0].value
# Out:
# amlvdaik10491222845.azurecr.io/mobilenetsoda:6
# amlvdaik10491222845
# 75f78a03-482f-4fd8-8c71-5ddc08f92726

# %% [markdown]
# ### Deployment file
# This is the deployment.json file that you will use to deploy your model.  Please see the other sample notebooks on using this file to deploy the new model you created.

# %%
file = open('./deployment-template.json')
contents = file.read()
contents = contents.replace('__MODULE_NAME', module_name)
contents = contents.replace('__REGISTRY_NAME', reg_name)
contents = contents.replace('__REGISTRY_USER_NAME', username)
contents = contents.replace('__REGISTRY_PASSWORD', password)
contents = contents.replace('__REGISTRY_IMAGE_LOCATION', image.image_location)
with open('./deployment.json', 'wt', encoding='utf-8') as output_file:
    output_file.write(contents)
